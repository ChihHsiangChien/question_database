# %%
import math
import re
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %%
passing_df = pd.read_csv('合併後的通過率與鑑別度.csv')  
print(passing_df)
# Out:
#        年度  科目  題號   鑑別度   通過率
# 0     109  國文   1  0.36  0.92
# 1     109  國文   2  0.32  0.91
# 2     109  國文   3  0.33  0.95
# 3     109  國文   4  0.41  0.91
# 4     109  國文   5  0.41  0.90
# 5     109  國文   6  0.49  0.87
# 6     109  國文   7  0.43  0.75
# 7     109  國文   8  0.43  0.73
# 8     109  國文   9  0.35  0.81
# 9     109  國文  10  0.43  0.70
# 10    109  國文  11  0.47  0.74
# 11    109  國文  12  0.52  0.74
# 12    109  國文  13  0.34  0.65
# 13    109  國文  14  0.51  0.74
# 14    109  國文  15  0.46  0.71
# 15    109  國文  16  0.56  0.68
# 16    109  國文  17  0.53  0.70
# 17    109  國文  18  0.49  0.65
# 18    109  國文  19  0.49  0.69
# 19    109  國文  20  0.41  0.60
# 20    109  國文  21  0.46  0.57
# 21    109  國文  22  0.42  0.49
# 22    109  國文  23  0.48  0.63
# 23    109  國文  24  0.38  0.50
# 24    109  國文  25  0.46  0.45
# 25    109  國文  26  0.35  0.55
# 26    109  國文  27  0.44  0.62
# 27    109  國文  28  0.42  0.50
# 28    109  國文  29  0.50  0.50
# 29    109  國文  30  0.36  0.48
# ...   ...  ..  ..   ...   ...
# 1969  110  自然  25  0.37  0.58
# 1970  110  自然  26  0.62  0.63
# 1971  110  自然  27  0.60  0.51
# 1972  110  自然  28  0.52  0.70
# 1973  110  自然  29  0.48  0.46
# 1974  110  自然  30  0.62  0.50
# 1975  110  自然  31  0.55  0.54
# 1976  110  自然  32  0.58  0.48
# 1977  110  自然  33  0.44  0.48
# 1978  110  自然  34  0.52  0.50
# 1979  110  自然  35  0.54  0.47
# 1980  110  自然  36  0.60  0.52
# 1981  110  自然  37  0.36  0.31
# 1982  110  自然  38  0.53  0.50
# 1983  110  自然  39  0.50  0.46
# 1984  110  自然  40  0.56  0.42
# 1985  110  自然  41  0.42  0.30
# 1986  110  自然  42  0.38  0.33
# 1987  110  自然  43  0.41  0.29
# 1988  110  自然  44  0.41  0.36
# 1989  110  自然  45  0.45  0.37
# 1990  110  自然  46  0.39  0.84
# 1991  110  自然  47  0.57  0.64
# 1992  110  自然  48  0.48  0.74
# 1993  110  自然  49  0.56  0.53
# 1994  110  自然  50  0.61  0.68
# 1995  110  自然  51  0.55  0.79
# 1996  110  自然  52  0.57  0.64
# 1997  110  自然  53  0.53  0.81
# 1998  110  自然  54  0.49  0.78
#
# [1999 rows x 5 columns]

# %%
df = pd.read_csv('database.csv', dtype=str, encoding = 'utf-8')

df
# Out:
#       序號       章           節            概念      次概念       考法   題組 題組題幹   題組圖1  \
# 0     14  01生命世界        1顯微鏡          染劑功能      NaN      NaN  NaN  NaN    NaN
# 1      4  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 2      5  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 3     13  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 4     21  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 5     23  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 6     24  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 7     27  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 8     29  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 9     31  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 10    74  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 11   608  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 12    28  01生命世界        1顯微鏡       顯微鏡移動方向      NaN      NaN  NaN  NaN    NaN
# 13    34  01生命世界        1顯微鏡       顯微鏡移動方向      NaN      NaN  NaN  NaN    NaN
# 14    33  01生命世界        1顯微鏡         顯微鏡構造      NaN      NaN  NaN  NaN    NaN
# 15     1  01生命世界   2動植物細胞的比較        細胞間的比較      NaN      NaN  NaN  NaN    NaN
# 16    19  01生命世界   2動植物細胞的比較        細胞間的比較      NaN      NaN  NaN  NaN    NaN
# 17    37  01生命世界   2動植物細胞的比較        細胞間的比較      NaN      NaN  NaN  NaN    NaN
# 18     2  01生命世界   2動植物細胞的比較       細胞構造的功能      NaN      NaN  NaN  NaN    NaN
# 19    11  01生命世界   2動植物細胞的比較       細胞構造的功能      NaN      NaN  NaN  NaN    NaN
# 20    12  01生命世界   2動植物細胞的比較       細胞構造的功能      NaN      NaN  NaN  NaN    NaN
# 21    22  01生命世界   2動植物細胞的比較       細胞構造的功能      NaN      NaN  NaN  NaN    NaN
# 22    40  01生命世界   2動植物細胞的比較       細胞構造的功能      NaN      NaN  NaN  NaN    NaN
# 23    15  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      粒線體  NaN  NaN    NaN
# 24    16  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      粒線體  NaN  NaN    NaN
# 25    32  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      粒線體  NaN  NaN    NaN
# 26    35  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      葉綠體  NaN  NaN    NaN
# 27    51  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      葉綠體  NaN  NaN    NaN
# 28    67  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      粒線體  NaN  NaN    NaN
# 29    85  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      NaN  NaN  NaN    NaN
# ..   ...     ...         ...           ...      ...      ...  ...  ...    ...
# 516  NaN    05恆定       1體溫恆定          調節體溫  調節體溫的方式      NaN  NaN  NaN    NaN
# 517  NaN    06生殖     5植物有性生殖          花的構造      NaN      NaN  NaN  NaN    NaN
# 518  NaN    11其他       1科學方法          實驗推論      NaN      NaN  NaN  NaN  m0343
# 519  NaN    09分類        4植物界         植物的特徵      NaN      NaN  NaN  NaN    NaN
# 520  NaN    11其他       1科學方法          實驗推論      NaN      NaN  NaN  NaN  m0344
# 521  NaN    07遺傳       1遺傳法則           NaN      NaN      NaN  NaN  NaN  m0345
# 522  NaN  01生命世界        1顯微鏡       顯微鏡移動方向      NaN      NaN  NaN  NaN    NaN
# 523  NaN    04協調       1神經系統     神經系統綜合性問題      NaN      NaN  NaN  NaN    NaN
# 524  NaN    09分類        5動物界      3脊椎動物的特徵      NaN  多種生物的比較  NaN  NaN  m0346
# 525  NaN    03運輸       2循環系統        血液循環路徑      NaN      NaN  NaN  NaN    NaN
# 526  NaN    10生態       2交互關係        食物網的分析      NaN      NaN  NaN  NaN  m0347
# 527  NaN    02養分         2酵素         酵素的活性      NaN     圖表判讀  NaN  NaN    NaN
# 528  NaN    11其他       1科學方法          實驗推論      NaN      NaN  NaN  NaN  m0352
# 529  NaN    08演化      1天擇與人擇         天擇的過程     解釋現象      NaN  NaN  NaN  m0352
# 530  NaN    08演化        4演化樹        判斷演化關係     共同祖先      NaN  NaN  NaN  m0353
# 531  NaN    08演化         2化石       化石與地層關係      NaN      NaN  NaN  NaN  m0353
# 532  NaN  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      NaN  NaN  NaN    NaN
# 533  NaN    04協調      2內分泌系統          血糖調控      NaN      NaN  NaN  NaN    NaN
# 534  NaN    06生殖       2無性生殖       無性生殖的特性      NaN      NaN  NaN  NaN    NaN
# 535  NaN    10生態      1族群與群集  從食物網預測生物放大現象      NaN      NaN  NaN  NaN  m0354
# 536  NaN    04協調       1神經系統        神經傳遞路徑      NaN      NaN  NaN  NaN    NaN
# 537  NaN    07遺傳       1遺傳法則     計算與分析遺傳機率      NaN      NaN  NaN  NaN    NaN
# 538  NaN  01生命世界     3物質如何交換         擴散的實驗      NaN      NaN  NaN  NaN  m0355
# 539  NaN    06生殖  1細胞分裂與減數分裂       染色體綜合問題      NaN      NaN  NaN  NaN  m0356
# 540  NaN  01生命世界   2動植物細胞的比較       粒線體與葉綠體      NaN      NaN  NaN  NaN  m0357
# 541  NaN  01生命世界        1顯微鏡     顯微鏡的視野與比較      NaN      NaN  NaN  NaN    NaN
# 542  NaN    05恆定       3水分恆定       泌尿系統的功能      NaN      NaN  NaN  NaN    NaN
# 543  NaN    08演化      1天擇與人擇            人擇      NaN      NaN  NaN  NaN    NaN
# 544  NaN    03運輸      1植物的運輸           維管束      NaN      NaN  NaN  NaN  m0358
# 545  NaN    03運輸      1植物的運輸           維管束      NaN      NaN  NaN  NaN    NaN
#
#     題組圖2  ...                              選項D     圖A     圖B     圖C     圖D  \
# 0    NaN  ...                    使細胞中的構造顏色深淺不同    NaN    NaN    NaN    NaN
# 1    NaN  ...                              NaN  m0002  m0003  m0004  m0005
# 2    NaN  ...                              NaN  m0007  m0008  m0009  m0010
# 3    NaN  ...                  先用乙再轉換到甲，視野亮度變亮    NaN    NaN    NaN    NaN
# 4    NaN  ...        若在甲看到模糊的影像，改換成乙就可以看到清晰的影像    NaN    NaN    NaN    NaN
# 5    NaN  ...                              NaN  m0012  m0013  m0014  m0015
# 6    NaN  ...    若想將附圖中的X點移到視野中央，應該將蟬翅樣本向左下方移動    NaN    NaN    NaN    NaN
# 7    NaN  ...                      目鏡15X、物鏡40X    NaN    NaN    NaN    NaN
# 8    NaN  ...                         丙，視野範圍縮小    NaN    NaN    NaN    NaN
# 9    NaN  ...                      目鏡15X、物鏡40X    NaN    NaN    NaN    NaN
# 10   NaN  ...                           更換高倍物鏡    NaN    NaN    NaN    NaN
# 11   NaN  ...                              NaN  m0023  m0024  m0025  m0022
# 12   NaN  ...                               左下    NaN    NaN    NaN    NaN
# 13   NaN  ...                               左下    NaN    NaN    NaN    NaN
# 14   NaN  ...                                丁    NaN    NaN    NaN    NaN
# 15   NaN  ...                              NaN  m0030  m0031  m0032  m0033
# 16   NaN  ...                         細胞核內的DNA    NaN    NaN    NaN    NaN
# 17   NaN  ...                    可觀察到呈半月形的保衛細胞    NaN    NaN    NaN    NaN
# 18   NaN  ...                   為氧化物質產生能量的主要場所    NaN    NaN    NaN    NaN
# 19   NaN  ...                 二者皆具有葉綠體，但不具有細胞壁    NaN    NaN    NaN    NaN
# 20   NaN  ...                       保衛細胞，因具細胞壁    NaN    NaN    NaN    NaN
# 21   NaN  ...                      丁能分解葡萄糖產生光能    NaN    NaN    NaN    NaN
# 22   NaN  ...                        僅乙細胞含有葉綠體    NaN    NaN    NaN    NaN
# 23   NaN  ...                              粒線體    NaN    NaN    NaN    NaN
# 24   NaN  ...                              粒線體    NaN    NaN    NaN    NaN
# 25   NaN  ...                             產生能量    NaN    NaN    NaN    NaN
# 26   NaN  ...                                丁    NaN    NaN    NaN    NaN
# 27   NaN  ...                              葉綠體    NaN    NaN    NaN    NaN
# 28   NaN  ...                       除葉以外的器官皆具有    NaN    NaN    NaN    NaN
# 29   NaN  ...                       此兩種作用皆無法進行    NaN    NaN    NaN    NaN
# ..   ...  ...                              ...    ...    ...    ...    ...
# 516  NaN  ...                   乙環境溫度＞體溫＞甲環境溫度    NaN    NaN    NaN    NaN
# 517  NaN  ...                               子房    NaN    NaN    NaN    NaN
# 518  NaN  ...  若將銀幣改成金幣進行相同的實驗，推測其檢測結果也是「未檢測出」    NaN    NaN    NaN    NaN
# 519  NaN  ...                        《維管束植物簡介》    NaN    NaN    NaN    NaN
# 520  NaN  ...                      平均分布於葉片上下表皮    NaN    NaN    NaN    NaN
# 521  NaN  ...                       丁：BB＜Bb＝bb    NaN    NaN    NaN    NaN
# 522  NaN  ...                           往左下角移動    NaN    NaN    NaN    NaN
# 523  NaN  ...                       經練習可縮短反應時間    NaN    NaN    NaN    NaN
# 524  NaN  ...                        丁：是否為體內受精    NaN    NaN    NaN    NaN
# 525  NaN  ...                        大靜脈和右心房之間    NaN    NaN    NaN    NaN
# 526  NaN  ...                    戊和庚同時為捕食和競爭關係    NaN    NaN    NaN    NaN
# 527  NaN  ...                              NaN  m0348  m0349  m0350  m0351
# 528  NaN  ...           若要撲殺乙蚊，選擇Y牌殺蟲劑較X牌殺蟲劑有效    NaN    NaN    NaN    NaN
# 529  NaN  ...       少數蚊子因沒有接觸到殺蟲劑，得以產生具有抵抗力的子代    NaN    NaN    NaN    NaN
# 530  NaN  ...                     與暴龍在白堊紀有共同祖先    NaN    NaN    NaN    NaN
# 531  NaN  ...            於同一層火山灰岩層中發現劍龍與三角龍的化石    NaN    NaN    NaN    NaN
# 532  NaN  ...                        粒線體位於細胞膜上    NaN    NaN    NaN    NaN
# 533  NaN  ...        激素甲可能由胰臟或腎上腺分泌，激素乙可能由胰臟分泌    NaN    NaN    NaN    NaN
# 534  NaN  ...                  酵母菌及其以出芽生殖產生的子代    NaN    NaN    NaN    NaN
# 535  NaN  ...                           僅丙、丁、己    NaN    NaN    NaN    NaN
# 536  NaN  ...                 經由大腦判斷而得知食物中混有苦瓜    NaN    NaN    NaN    NaN
# 537  NaN  ...     若親代紫花植株和第一子代紫花植株雜交，不可能產生白花植株    NaN    NaN    NaN    NaN
# 538  NaN  ...                            甲＞丙＞乙    NaN    NaN    NaN    NaN
# 539  NaN  ...                        甲：花粉，乙：胚珠    NaN    NaN    NaN    NaN
# 540  NaN  ...                        乙可能是次級消費者    NaN    NaN    NaN    NaN
# 541  NaN  ...                    轉動調節輪使載物臺向下移動    NaN    NaN    NaN    NaN
# 542  NaN  ...                              輸尿管    NaN    NaN    NaN    NaN
# 543  NaN  ...                    比辣椒植株更能適應自然環境    NaN    NaN    NaN    NaN
# 544  NaN  ...                              NaN  m0359  m0360  m0361  m0362
# 545  NaN  ...                         光合作用，韌皮部    NaN    NaN    NaN    NaN
#
#               出處 答案  原題號   鑑別度   通過率
# 0       092基本學測一  D  NaN   NaN   NaN
# 1       090基測題本一  A  NaN   NaN   NaN
# 2       094基本學測二  D  NaN   NaN   NaN
# 3        104教育會考  A   15  0.55  0.53
# 4       099基本學測二  A  NaN   NaN   NaN
# 5       093基本學測一  C  NaN   NaN   NaN
# 6       097基本學測一  B  NaN   NaN   NaN
# 7       098基本學測二  A  NaN   NaN   NaN
# 8        105教育會考  D   14   0.5   0.6
# 9        102基本學測  A  NaN   NaN   NaN
# 10      100基本學測一  B  NaN   NaN   NaN
# 11       109教育會考  D   18  0.49  0.52
# 12      091基本學測一  D  NaN   NaN   NaN
# 13      091基本學測二  A  NaN   NaN   NaN
# 14      090基本學測二  C  NaN   NaN   NaN
# 15      092基本學測二  B  NaN   NaN   NaN
# 16      094基測題本一  D  NaN   NaN   NaN
# 17      095基本學測一  A  NaN   NaN   NaN
# 18      091基本學測一  B  NaN   NaN   NaN
# 19      090基本學測一  C  NaN   NaN   NaN
# 20       108教育會考  D    4  0.49  0.78
# 21      098基本學測二  A  NaN   NaN   NaN
# 22       106教育會考  D   18  0.51  0.68
# 23       101基本學測  D  NaN   NaN   NaN
# 24      096基本學測一  D  NaN   NaN   NaN
# 25      099基本學測一  D  NaN   NaN   NaN
# 26       107教育會考  C   19  0.51  0.63
# 27      098基本學測一  D  NaN   NaN   NaN
# 28       103教育會考  C   34  0.43  0.26
# 29       105教育會考  C    7  0.39  0.77
# ..           ... ..  ...   ...   ...
# 516      110教育會考  D    4   NaN   NaN
# 517      110教育會考  C    6   NaN   NaN
# 518      110教育會考  A    7   NaN   NaN
# 519      110教育會考  A   10   NaN   NaN
# 520      110教育會考  C   11   NaN   NaN
# 521      110教育會考  B   19   NaN   NaN
# 522      110教育會考  A   25   NaN   NaN
# 523      110教育會考  A   28   NaN   NaN
# 524      110教育會考  B   31   NaN   NaN
# 525      110教育會考  A   34   NaN   NaN
# 526      110教育會考  D   36   NaN   NaN
# 527      110教育會考  C   42   NaN   NaN
# 528      110教育會考  C   48   NaN   NaN
# 529      110教育會考  C   49   NaN   NaN
# 530      110教育會考  B   52   NaN   NaN
# 531      110教育會考  B   54   NaN   NaN
# 532  110教育會考(補考)  A    1   NaN   NaN
# 533  110教育會考(補考)  D    2   NaN   NaN
# 534  110教育會考(補考)  B    5   NaN   NaN
# 535  110教育會考(補考)  D   12   NaN   NaN
# 536  110教育會考(補考)  D   14   NaN   NaN
# 537  110教育會考(補考)  C   15   NaN   NaN
# 538  110教育會考(補考)  B   16   NaN   NaN
# 539  110教育會考(補考)  C   22   NaN   NaN
# 540  110教育會考(補考)  D   23   NaN   NaN
# 541  110教育會考(補考)  B   30   NaN   NaN
# 542  110教育會考(補考)  A   31   NaN   NaN
# 543  110教育會考(補考)  C   32   NaN   NaN
# 544  110教育會考(補考)  A   50   NaN   NaN
# 545  110教育會考(補考)  A   51   NaN   NaN
#
# [546 rows x 27 columns]

# %%
year = 110
number = 3
ref1 = passing_df['年度'] == year
ref2 = passing_df['科目'] == '自然'
ref3 = passing_df['題號'] == number

dis_index = passing_df[ref1 & ref2 & ref3]['鑑別度'].values.item(0)
pass_index = passing_df[ref1 & ref2 & ref3]['通過率'].values.item(0)
print(dis_index, pass_index)
# Out:
# 0.58 0.71

# %%
year = 110


df_filter1 = df['出處'].str.contains(str(year))
df_filter2 = ~df['出處'].str.contains(str('補考'))

df_year = df[df_filter1 & df_filter2]

for num in  df_year['原題號']:
    
    ref1 = passing_df['年度'] == year
    ref2 = passing_df['科目'] == '自然'
    ref3 = passing_df['題號'] == int(num)
    
    dis_index  = passing_df[ref1 & ref2 & ref3]['鑑別度'].values.item(0)
    pass_index = passing_df[ref1 & ref2 & ref3]['通過率'].values.item(0)

    print(str(year), num , dis_index, pass_index)
    
    df_filter2 = df['原題號'] == num

    
    df.loc[ df_filter1 & df_filter2 , '鑑別度'] = dis_index
    df.loc[ df_filter1 & df_filter2 , '通過率'] = pass_index
# Out:
# 110 4 0.48 0.81
# 110 6 0.53 0.73
# 110 7 0.55 0.65
# 110 10 0.43 0.63
# 110 11 0.51 0.6
# 110 19 0.61 0.64
# 110 25 0.37 0.58
# 110 28 0.52 0.7
# 110 31 0.55 0.54
# 110 34 0.52 0.5
# 110 36 0.6 0.52
# 110 42 0.38 0.33
# 110 48 0.48 0.74
# 110 49 0.56 0.53
# 110 52 0.57 0.64
# 110 54 0.49 0.78

# %%
ref1 = passing_df['年度'] == 110
ref2 = passing_df['科目'] == '自然'
ref3 = passing_df['題號'] == 2

passing_df[ref1 & ref2 & ref3]['鑑別度'].values.item(0)
# Out:
# 0.4

# %%
df.to_csv('database2.csv', encoding = 'utf_8')
