# %%
import pdfplumber
import PyPDF2

from PIL import Image

import requests
import re


import pandas as pd

# %%
"""
    https://cap.rcpet.edu.tw/exam/103/103P_Nature.pdf
    https://cap.rcpet.edu.tw/exam/104/104P_Nature.pdf
    https://cap.rcpet.edu.tw/exam/105/105P_Nature150DPI.pdf
    https://cap.rcpet.edu.tw/exam/106/106P_Nature150DPI.pdf
    https://cap.rcpet.edu.tw/exam/107/107P_Nature150DPI.pdf
    https://cap.rcpet.edu.tw/exam/108/108P_Nature150DPI.pdf
    https://cap.rcpet.edu.tw/exam/109/109P_Nature150DPI.pdf
    
    https://cap.rcpet.edu.tw/exam/103/103P_Chinese.pdf    
    https://cap.rcpet.edu.tw/exam/103/103P_English.pdf
    https://cap.rcpet.edu.tw/exam/103/103P_Math.pdf
    https://cap.rcpet.edu.tw/exam/103/103P_Society.pdf
    https://cap.rcpet.edu.tw/exam/103/103P_Nature.pdf        
    https://cap.rcpet.edu.tw/exam/103/103P_Writing.pdf
"""

subjects = ['Chinese',
            'English',
            'Math',
            'Society',
            'Nature']

url_1 = 'https://cap.rcpet.edu.tw/exam/'


url_lists = []        #會考檔案的網址
filename_lists = []   #會考檔案的網址

for year in range(103, 110):
    for subject in subjects:
        if year < 105 or year == 107 :
            url_DPI = ''
        else:
            url_DPI = '150DPI'

        new_url = url_1 + str(year) + '/' + str(year) + 'P_' + subject + url_DPI + '.pdf'
        print(new_url)        
        filename = str(year) + '_' + subject + '.pdf'
        
        url_lists.append(new_url)
        filename_lists.append(filename)
url_lists
# Out:
# https://cap.rcpet.edu.tw/exam/103/103P_Chinese.pdf
# https://cap.rcpet.edu.tw/exam/103/103P_English.pdf
# https://cap.rcpet.edu.tw/exam/103/103P_Math.pdf
# https://cap.rcpet.edu.tw/exam/103/103P_Society.pdf
# https://cap.rcpet.edu.tw/exam/103/103P_Nature.pdf
# https://cap.rcpet.edu.tw/exam/104/104P_Chinese.pdf
# https://cap.rcpet.edu.tw/exam/104/104P_English.pdf
# https://cap.rcpet.edu.tw/exam/104/104P_Math.pdf
# https://cap.rcpet.edu.tw/exam/104/104P_Society.pdf
# https://cap.rcpet.edu.tw/exam/104/104P_Nature.pdf
# https://cap.rcpet.edu.tw/exam/105/105P_Chinese150DPI.pdf
# https://cap.rcpet.edu.tw/exam/105/105P_English150DPI.pdf
# https://cap.rcpet.edu.tw/exam/105/105P_Math150DPI.pdf
# https://cap.rcpet.edu.tw/exam/105/105P_Society150DPI.pdf
# https://cap.rcpet.edu.tw/exam/105/105P_Nature150DPI.pdf
# https://cap.rcpet.edu.tw/exam/106/106P_Chinese150DPI.pdf
# https://cap.rcpet.edu.tw/exam/106/106P_English150DPI.pdf
# https://cap.rcpet.edu.tw/exam/106/106P_Math150DPI.pdf
# https://cap.rcpet.edu.tw/exam/106/106P_Society150DPI.pdf
# https://cap.rcpet.edu.tw/exam/106/106P_Nature150DPI.pdf
# https://cap.rcpet.edu.tw/exam/107/107P_Chinese.pdf
# https://cap.rcpet.edu.tw/exam/107/107P_English.pdf
# https://cap.rcpet.edu.tw/exam/107/107P_Math.pdf
# https://cap.rcpet.edu.tw/exam/107/107P_Society.pdf
# https://cap.rcpet.edu.tw/exam/107/107P_Nature.pdf
# https://cap.rcpet.edu.tw/exam/108/108P_Chinese150DPI.pdf
# https://cap.rcpet.edu.tw/exam/108/108P_English150DPI.pdf
# https://cap.rcpet.edu.tw/exam/108/108P_Math150DPI.pdf
# https://cap.rcpet.edu.tw/exam/108/108P_Society150DPI.pdf
# https://cap.rcpet.edu.tw/exam/108/108P_Nature150DPI.pdf
# https://cap.rcpet.edu.tw/exam/109/109P_Chinese150DPI.pdf
# https://cap.rcpet.edu.tw/exam/109/109P_English150DPI.pdf
# https://cap.rcpet.edu.tw/exam/109/109P_Math150DPI.pdf
# https://cap.rcpet.edu.tw/exam/109/109P_Society150DPI.pdf
# https://cap.rcpet.edu.tw/exam/109/109P_Nature150DPI.pdf
# ['https://cap.rcpet.edu.tw/exam/103/103P_Chinese.pdf',
#  'https://cap.rcpet.edu.tw/exam/103/103P_English.pdf',
#  'https://cap.rcpet.edu.tw/exam/103/103P_Math.pdf',
#  'https://cap.rcpet.edu.tw/exam/103/103P_Society.pdf',
#  'https://cap.rcpet.edu.tw/exam/103/103P_Nature.pdf',
#  'https://cap.rcpet.edu.tw/exam/104/104P_Chinese.pdf',
#  'https://cap.rcpet.edu.tw/exam/104/104P_English.pdf',
#  'https://cap.rcpet.edu.tw/exam/104/104P_Math.pdf',
#  'https://cap.rcpet.edu.tw/exam/104/104P_Society.pdf',
#  'https://cap.rcpet.edu.tw/exam/104/104P_Nature.pdf',
#  'https://cap.rcpet.edu.tw/exam/105/105P_Chinese150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/105/105P_English150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/105/105P_Math150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/105/105P_Society150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/105/105P_Nature150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/106/106P_Chinese150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/106/106P_English150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/106/106P_Math150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/106/106P_Society150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/106/106P_Nature150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/107/107P_Chinese.pdf',
#  'https://cap.rcpet.edu.tw/exam/107/107P_English.pdf',
#  'https://cap.rcpet.edu.tw/exam/107/107P_Math.pdf',
#  'https://cap.rcpet.edu.tw/exam/107/107P_Society.pdf',
#  'https://cap.rcpet.edu.tw/exam/107/107P_Nature.pdf',
#  'https://cap.rcpet.edu.tw/exam/108/108P_Chinese150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/108/108P_English150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/108/108P_Math150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/108/108P_Society150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/108/108P_Nature150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/109/109P_Chinese150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/109/109P_English150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/109/109P_Math150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/109/109P_Society150DPI.pdf',
#  'https://cap.rcpet.edu.tw/exam/109/109P_Nature150DPI.pdf']

# %%
#下載pdf
#解析url的filename
i = 0
for url in url_lists:
    r = requests.get(url, allow_redirects=True)
    open('會考題目/' + filename_lists[i], 'wb').write(r.content)
    print(filename_lists[i])
    i += 1

# %%
pdffile ='會考題目/' + filename_lists[0]     #pdf檔路徑及檔名
pdf = pdfplumber.open(pdffile)
p0 = pdf.pages[3]
text = p0.extract_text()       #讀文字
print(pdffile)
print(text)
# Out:
# 會考題目/103_Society.pdf
# None

# %%
# Out:
# [<Page:1>,
#  <Page:2>,
#  <Page:3>,
#  <Page:4>,
#  <Page:5>,
#  <Page:6>,
#  <Page:7>,
#  <Page:8>,
#  <Page:9>,
#  <Page:10>,
#  <Page:11>]

# %%
def extract_image(page):
    try:
        if '/XObject' in page['/Resources']:
            xObject = page['/Resources']['/XObject'].getObject()
            for obj in xObject:
                if xObject[obj]['/Subtype'] == '/Image':
                    size = (xObject[obj]['/Width'], xObject[obj]['/Height'])
                    data = xObject[obj].getData()
                    if xObject[obj]['/ColorSpace'] == '/DeviceRGB':
                        mode = "RGB"
                    else:
                        mode = "P"
                    # 保存图片的文件名前缀
                    img_pre = str(int(time.time()*1000))
                    if '/Filter' in xObject[obj]:
                        if xObject[obj]['/Filter'] == '/FlateDecode':
                            img = Image.frombytes(mode, size, data)
                            img.save(img_pre + ".png")
                        elif xObject[obj]['/Filter'] == '/DCTDecode':
                            img = open(img_pre + ".jpg", "wb")
                            img.write(data)
                            img.close()
                        elif xObject[obj]['/Filter'] == '/JPXDecode':
                            img = open(img_pre + ".jp2", "wb")
                            img.write(data)
                            img.close()
                        elif xObject[obj]['/Filter'] == '/CCITTFaxDecode':
                            img = open(img_pre + ".tiff", "wb")
                            img.write(data)
                            img.close()
                    else:
                        img = Image.frombytes(mode, size, data)
                        img.save(img_pre + ".png")
        else:
            print("no image")
    except:
        print("image extract fail")

# %%
def extract_content(pdf_path):
    # 内容提取，使用 pdfplumber 打开 PDF，用于提取文本
    with pdfplumber.open(pdf_path) as pdf_file:
        # 使用 PyPDF2 打开 PDF 用于提取图片
        pdf_image_reader = PyPDF2.PdfFileReader(open(pdf_path, "rb"))
        print(pdf_image_reader.getNumPages())

        content = ''
        # len(pdf.pages)为PDF文档页数，一页页解析
        for i in range(len(pdf_file.pages)):
            #print("第 %s 頁" % i)
            # pdf.pages[i] 是读取PDF文档第i+1页
            page_text = pdf_file.pages[i]
            # page.extract_text()函数即读取文本内容
            page_content = page_text.extract_text()
            if page_content:
                content = content + page_content + "\n"
                #print(page_content)

            # 提取图片
            #page_image = pdf_image_reader.getPage(pageNumber=i)
            #extract_image(page_image)
    return content

# %%
#取得pdf內文
filename = filename_lists[17]
pdf_file ='會考題目/' + filename     #pdf檔路徑及檔名
print(filename)
text = extract_content(pdf_file)

#將各題分開放在list
matches = re.findall('\\n(\d{1,2}\.{1}\s{2}.*?？)', text, re.DOTALL)
print(matches)
# Out:
# 106_Math.pdf
# 11
# ['1.  算式(−2) ×  −5  −  −3 之值為何？', '2.  下列哪一個選項中的等式成立？', '3.  計算 6x•(3 − 2x) 的結果，與下列哪一個式子相同？', '4.  若阿光以四種不同的方式連接正六邊形 ABCDEF 的兩條對角線，連接後的\n情形如下列選項中的圖形所示，則下列哪一個圖形不是線對稱圖形？', '5.  已知坐標平面上有兩直線相交於一點 (2,a)， 且兩直線的方程式分別為 \n2x + 3y = 7、  3x − 2y = b，其中 a、  b 為兩數。求 a + b 之值為何？', '6.  阿信、小怡兩人打算搭乘同一班次電車上學。若此班次電車共有 5 節車廂，且\n阿信從任意一節車廂上車的機會相等，小怡從任意一節車廂上車的機會相等，\n則兩人從同一節車廂上車的機率為何？', '7.  平面上有 A、  B、C 三點，其中 AB = 3，  BC = 4，  AC = 5。若分別以 A、  B、  C\n為圓心，半徑長為 2 畫圓，畫出圓 A、圓 B、圓 C，則下列敘述何者正確？', '8.  下列選項中所表示的數，哪一個與 252 的最大公因數為 42 ？', '9.  某高中的籃球隊成員中，一、二年級的成員共有 8 人，三年級的成員有 3 人。\n一、二年級的成員身高 ( 單位：公分 ) 如下：\n172、 172、 174、 174、176、176、178、178 \n若隊中所有成員的平均身高為 178 公分，    則隊中三年級成員的平均身高為幾公分？', '10.  已知在卡樂芙超市內購物總金額超過 190 元時，  購物總金額有打八折的優惠。\n安妮帶 200 元到卡樂芙超市買棒棒糖，若棒棒糖每根 9 元，則她最多可買多少\n根棒棒糖？', '11.  如圖(一) ，  △ABC 中，  D、  E 兩點分別在 AB、  BC上。若 \nAD ： DB = CE ： EB = 2：3，則 △ DBE 與 △ ADC \n的面積比為何？', '12.  一元二次方程式 x2 − 8x = 48 可表示成 (x − a)2 = 48 + b 的形式，其中 a、  b\n為整數。求 a + b 之值為何？', '13.  已知坐標平面上有一長方形 ABCD，其坐標分別為 A(0,0)、  B(2,0)、C(2,1) 、 \nD(0,1)。今固定 B 點並將此長方形依順時針方向旋轉，如圖 ( 二 ) 所示。\n       若旋轉後 C 點的坐標為 (3,0)，則旋轉後 D 點的坐標為何？', '14.  圖 ( 三 ) 為平面上五條直線 L 、  L 、  L 、  L 、  L 相交的情形。根據圖中標示\n1 2 3 4 5 \n的角度，判斷下列敘述何者正確？', '15.  威立到小吃店買水餃，他身上帶的錢恰好等於 15 粒蝦仁水餃或 20 粒韭菜\n水餃的價錢。若威立先買了 9 粒蝦仁水餃，則他身上剩下的錢恰好可買多少粒\n韭菜水餃？', '16.  將圖 ( 四 ) 中五邊形紙片 ABCDE 的 A 點以 BE 為摺線往下摺， A 點恰好落\n在 CD 上，如圖 ( 五 ) 所示。再分別以圖 ( 五 ) 的 AB、AE 為摺線，將 C、  D\n兩點往上摺，使得 A、  B、C、D、E 五點均在同一平面上，如圖 ( 六 ) 所示。\n若圖 ( 四 ) 中 ∠A = 124°，則圖 ( 六 ) 中 ∠CAD 的度數為何？', '17.  若 a、  b 為兩質數且相差 2，則 ab + 1 之值可能為下列何者？', '18.  如圖 ( 七 )，  O 為銳角三角形 ABC 的外心，四邊形 OCDE 為正方形，其中 \nE 點在 △ABC 的外部。判斷下列敘述何者正確？', '19.  圖 ( 八 ) 為互相垂直的兩直線將四邊形 ABCD 分成四個區域的情形。\n      若 ∠A = 100°，  ∠B = ∠D = 85°，  ∠C = 90°，  則根據圖中標示的角， 判斷\n        下列 ∠1、 ∠2、 ∠3 的大小關係，  何者正確？', '20.  圖(九)的數線上有 O、  A、B 三點，其中 O 為原點，A 點所表示的數為 106。根據\n圖中數線上這三點之間的實際距離進行估計，下列何者最接近 B 點所表示的數？', '21.  如圖 ( 十 )，△ ABC、△ ADE  中，C、E 兩點分別在 AD、AB 上，且 \nBC 與 DE 相交於 F 點。若 ∠A = 90°，∠B = ∠D = 30°，AC = AE = 1，則\n       四邊形 AEFC 的周長為何？', '22.  已知坐標平面上有兩個二次函數 y = a(x + 1)(x − 7)、  y = b(x + 1)(x − 15) 的\n圖形，其中 a、b 為整數。判斷將二次函數 y = b(x + 1)(x − 15) 的圖形依下列\n哪一種方式平移後，會使得此兩圖形的對稱軸重疊？', '23.  圖 ( 十一 ) 為阿輝、小薰一起到商店分別買了數杯飲料與在家分飲料的經過。 \n2000 (cid:502)\n圖(十一)\n若每杯飲料的價格均相等，  則根據圖中的對話，判斷阿輝買了多少杯飲料？', '24.  如圖(十二)，水平桌面上有個內部裝水的長方體箱子，箱內有一個與底面垂直的\n隔板，且隔板左右兩側的水面高度分別為 40 公分、50 公分。今將隔板抽出，若\n過程中箱內的水量未改變，且不計箱子及隔板厚度，則根據圖中的數據，求隔板\n抽出後水面靜止時，  箱內的水面高度為多少公分？', '25.  如圖 ( 十三 )，某計算機中有 、  、  三個按鍵，以下\n是這三個按鍵的功能。\n        1.  ：將螢幕顯示的數變成它的正平方根， C √ 1/x x 2 +_\n           例如：螢幕顯示的數為 49 時，按下   後會變成 7。 CE 7 8 9 ÷\n        2.  ：將螢幕顯示的數變成它的倒數， MC 4 5 6 +\n_\n           例如：螢幕顯示的數為 25 時，按下   後會變成 0.04。 MR 1 2 3\nM+ 0 . = +\n        3.   ：將螢幕顯示的數變成它的平方，\n圖(十三)\n           例如：螢幕顯示的數為 6 時，按下   後會變成 36。\n若螢幕顯示的數為 100 時，小劉第一下按  ，第二下按  ，第三下按  ，\n之後以  、   、    的順序輪流按， 則當他按了第 100 下後螢幕顯示的數\n是多少？', '26.  圖 ( 十四 ) 為兩正方形 ABCD、  BPQR 重疊的情形，其中 R 點在 AD 上，CD \n與 QR 相交於 S 點。若兩正方形 ABCD、BPQR 的面積分別為 16、25 ，則\n四邊形 RBCS 的面積為何？']

# %%
df = pd.DataFrame()

for year in range(104,105):
    for subject in subjects:
        #取得pdf內文
        filename = str(year) + '_' + subject

        pdf_file ='會考題目/' + filename + '.pdf'    #pdf檔路徑及檔名
        print(filename)
        text = extract_content(pdf_file)

        #將各題分開放在list
        matches = re.findall('\\n(\d{1,2}\.{1}\s{2}.*?？)', text, re.DOTALL)
        print(matches)

        #取出題號
        question_num_list = []
        for question in matches:
            question_num = re.match('^(\d{1,2})', question, re.DOTALL)
            question_num_list.append(question_num[0])
        question_num_list

        question_list = []
        for i in range(len(matches)):
            print(year, subject, question_num_list[i] , matches[i] )
            question = [year, subject, question_num_list[i] , matches[i]]
            question_list.append(question)

        df2 = pd.DataFrame(question_list , columns = ['year', 'subject','num','question'])
        df.append(df2,ignore_index = True)
# Out:
# 104_Chinese
# 14
# ['1.  小敬搬新家，阿嬌欲送禮金表達祝賀之意。下列題辭，何者最適合寫在賀儀封套上？', '2.  下列文句，何者文意最為通暢？', '3.  「當部分亞洲國家為了生產足夠的稻米而焦頭爛額之際，泰國稻米的產量卻多到一\n年出口九百萬噸，是全世界最大稻米輸出國。泰國成為世界米倉的原因是：民營企\n業非常有效率，擁有大量平坦肥沃的三角洲和充沛的水源，再加上政府機關支\n持民間銀行貸款給小農購買種子、肥料。以上種種，使泰國在米糧危機中占盡\n利益。」這段文字的主旨為下列何者？', '4.  下列詞語「」中的字音，何組相同？', '5.  「時然後言，人不厭其言。」這句話的涵義，與下列何者最接近？', '6.  下列詞語，何者沒有錯別字？', '7.  下列選項「」中的疊字，何者是用來描摹聲音的狀聲詞？', '8.  小王和小林第一次碰面，下列寒暄的語句，何者最不適合出現在他們的對話中？', '9.  「物產豐富」中的「物產」是本句的主語。下列各選項「」中的語詞，何者不做\n主語使用？', '10.  「豆，古代食器，用以盛肉醬一類食物，器淺如盤，下有一足，大多數有蓋。春秋\n以後，豆增多，側有兩環，下具高足。到戰國時期，器腹變深，蓋上有捉手，\n可以仰置。」根據這段敘述，下列何者最可能是戰國時期的「豆」器？', '11.  「有農夫種茄不活，求計於農務司，司吏曰：『此不難，每茄根下埋一文即活。』\n問其何故，答曰：『有錢者生，無錢者死。』」這段文字主要在揭露世間哪一種\n醜態？', '12.  下列詩句，何者與「亂花漸欲迷人眼，淺草纔能沒馬蹄」所描述的季節相同？', '13.  一家書店的外牆寫著：「在我看來，托爾斯泰和杜思妥也夫斯基比隔壁鄰居更真\n實。更奇怪的是，早在我尚未出生以前，杜思妥也夫斯基就在一本叫做《白痴》\n的書中，寫出了我的人生故事。」根據這段文字，下列推論何者最恰當？', '14.  「我只希望，我們的距離□我和所有野鳥的距離，永遠是這樣接近。」句中空格\n處填入下列哪一種標點符號最恰當？', '15.  「我的記憶運作得像一面蜘蛛網。不重要的事物，比如風，就讓它們過去；但\n捕獲的蒼蠅就懸掛在網上加以儲存，直到我那心智的蜘蛛需要時再吃掉。」這\n段文字的涵義，與下列何者最接近？', '16.  「盡忠益時者雖仇必賞，犯法怠慢者雖親必罰。」這句話所強調的執法原則，\n與下列何者相去最遠？', '17.  「細菌和殺死它們的抗生素之間的戰爭，就如同大國之間的軍備競爭，精益求\n精，更相勝出，__________。」畫線處填入下列何者最能說明上述比喻的內涵？', '18.  袁宏道與友人書云：「人情必有所寄，然後能樂。故有以弈為寄，有以色為寄，\n有以技為寄，有以文為寄。古之達人，高人一層，只是他情有所寄，不肯浮泛\n虛度光景。」這段文字的主要涵義，與下列何者最接近？', '19.  下列文句，何者有語病？', '20.  民初某學者仍留著前朝的舊髮式，拖著一條辮子去北大授課，學生哄堂大笑，他\n說：「我的辮子一剪就沒有了，但你們心中的辮子恐怕就沒有那麼容易剪掉了。」\n他話中的涵義，與下列何者最接近？', '21.  「如果每個人都是特別的，那就沒有一個特別；如果每個人都得到一個獎\n杯，獎杯就變得毫無意義。生活最甜美的樂趣，在於承認自己並不特別。」\n這段文字的涵義，與下列何者最接近？', '22.  下列文句，何者用字完全正確？', '23.  「書，飢讀之以當肉；寒讀之以當裘；孤寂而讀之，以當友朋；幽憂而讀之，\n以當金石琴瑟也。」這句話的涵義，與下列何者最接近？', '24.  白居易〈題山石榴花〉：「一叢千朵壓闌干，剪碎紅綃卻作團。風嫋舞腰香不盡，\n露銷妝臉淚新乾。薔薇帶刺攀應懶，菡萏  生泥玩亦難。爭及  此花檐戶下，任人\n1  2 \n採弄盡人看。」下列關於這首詩的說明，何者錯誤？', '25.  「如果有人認為文學是不著塵色的白裳，那是因為他遺忘了『現實』這一件緇衣。\n崇拜詩聖杜甫的人，不見得讀得懂『杜詩』，但我們不難想像，當杜甫自外訪\n友歸來，一進門問他老妻第一句話，也許是：『尚有油鹽否？', '26.  下列文句「」中的字詞，何者意義前後相同？', '27.  「余猶及見老儒先生，自言其少時，欲求《史記》、《漢書》而不可得，幸而得\n之，皆手自書，日夜誦讀，惟恐不及。近歲市人轉相摹刻諸子百家之書，日傳萬\n紙，學者之於書，多且易致如此，其文詞學術，當倍蓰  於昔人，而後生科舉之\n1 \n士皆束書不觀，游談無根，此又何也？', '28.  下列文句「」中的成語，何者使用最恰當？', '29. \n有盜年羹堯大將軍坐騎者，為岳鍾琦部所執，將科以刑。年知之即索\n此人，__________。年因語岳曰：「此人敢盜余坐騎，膽量可知，故吾宥其\n罪，用其所長，料必能達成此一使命也。」其識人、推恩也，悉類此。\n根據文意脈絡判斷，畫線處應填入下列何者最恰當？', '31.  「世人以竹、木、牙、骨之類為『叫子』，置人喉中吹之，能作人言，謂之『嗓\n叫子』。嘗有病瘖  者，為人所誣，煩冤無以自言。聽訟者試取叫子，令嗓之，\n1 \n作聲如傀儡子  ，粗能辨其一二，其冤獲伸。此亦可記也。」根據這段文字，下\n2\n列有關「叫子」的敘述，何者無法明確得知？', '32. \n相較於廣大的平民百姓，政務官、事務官、民意代表、媒體記者、知\n識分子都是掌有權力的人。政務官負責政策的擘劃，事務官負責政策的執\n行，民意代表負責審查，媒體記者負責監督，知識分子用知識和筆做時\n代的眼光。細究之下，每一種權力都很可怕，它可以興邦，可以覆邦，影\n響這一代人的此刻，下一代人的未來。掌權的人對自己手中所握有的權\n力——權  力的性質、權力的界限、權力的責任，是否深思過呢？', '33.  以下是小臻在國文課所做的筆記，一時大意寫錯一處。筆記中的錯處應是下列\n何者？', '34.  根據本文，「我相信對那些有慧根的人，這幾個字也就夠了。留一點餘味讓人\n咀嚼體會，豈不更好？', '35.  下列何者最可能是本文所要傳達的人生態度？', '36.  下列何者最可能是作者說自己是「今之古人」的原因？', '37.  本文的主要內容，最可能是下列何者？', '38.  下列詩句的說明，何者正確？', '39.  關於本詩的寫作手法，下列敘述何者正確？', '40.  根據本文，關於雪山山脈的敘述，下列何者錯誤？', '41.  根據本文，下列關於淡水河水域的敘述，何者正確？', '42.  關於本文的寫作手法，下列敘述何者正確？', '43.  關於本文所述的「知縣」一職，下列說明何者正確？', '44.  根據本文，下列何人最符合遴選資格？', '45.  根據本文，景公的作為最適合以下列何者來形容？', '46.  本文呈現了晏子在政治上的哪一種智慧？', '47.  下列文句「」中語詞的意義，何者說明正確？', '48.  根據本文，關於賈堅與荀羨攻守的過程，下列敘述何者正確？']
# 104 Chinese 1 1.  小敬搬新家，阿嬌欲送禮金表達祝賀之意。下列題辭，何者最適合寫在賀儀封套上？
# 104 Chinese 2 2.  下列文句，何者文意最為通暢？
# 104 Chinese 3 3.  「當部分亞洲國家為了生產足夠的稻米而焦頭爛額之際，泰國稻米的產量卻多到一
# 年出口九百萬噸，是全世界最大稻米輸出國。泰國成為世界米倉的原因是：民營企
# 業非常有效率，擁有大量平坦肥沃的三角洲和充沛的水源，再加上政府機關支
# 持民間銀行貸款給小農購買種子、肥料。以上種種，使泰國在米糧危機中占盡
# 利益。」這段文字的主旨為下列何者？
# 104 Chinese 4 4.  下列詞語「」中的字音，何組相同？
# 104 Chinese 5 5.  「時然後言，人不厭其言。」這句話的涵義，與下列何者最接近？
# 104 Chinese 6 6.  下列詞語，何者沒有錯別字？
# 104 Chinese 7 7.  下列選項「」中的疊字，何者是用來描摹聲音的狀聲詞？
# 104 Chinese 8 8.  小王和小林第一次碰面，下列寒暄的語句，何者最不適合出現在他們的對話中？
# 104 Chinese 9 9.  「物產豐富」中的「物產」是本句的主語。下列各選項「」中的語詞，何者不做
# 主語使用？
# 104 Chinese 10 10.  「豆，古代食器，用以盛肉醬一類食物，器淺如盤，下有一足，大多數有蓋。春秋
# 以後，豆增多，側有兩環，下具高足。到戰國時期，器腹變深，蓋上有捉手，
# 可以仰置。」根據這段敘述，下列何者最可能是戰國時期的「豆」器？
# 104 Chinese 11 11.  「有農夫種茄不活，求計於農務司，司吏曰：『此不難，每茄根下埋一文即活。』
# 問其何故，答曰：『有錢者生，無錢者死。』」這段文字主要在揭露世間哪一種
# 醜態？
# 104 Chinese 12 12.  下列詩句，何者與「亂花漸欲迷人眼，淺草纔能沒馬蹄」所描述的季節相同？
# 104 Chinese 13 13.  一家書店的外牆寫著：「在我看來，托爾斯泰和杜思妥也夫斯基比隔壁鄰居更真
# 實。更奇怪的是，早在我尚未出生以前，杜思妥也夫斯基就在一本叫做《白痴》
# 的書中，寫出了我的人生故事。」根據這段文字，下列推論何者最恰當？
# 104 Chinese 14 14.  「我只希望，我們的距離□我和所有野鳥的距離，永遠是這樣接近。」句中空格
# 處填入下列哪一種標點符號最恰當？
# 104 Chinese 15 15.  「我的記憶運作得像一面蜘蛛網。不重要的事物，比如風，就讓它們過去；但
# 捕獲的蒼蠅就懸掛在網上加以儲存，直到我那心智的蜘蛛需要時再吃掉。」這
# 段文字的涵義，與下列何者最接近？
# 104 Chinese 16 16.  「盡忠益時者雖仇必賞，犯法怠慢者雖親必罰。」這句話所強調的執法原則，
# 與下列何者相去最遠？
# 104 Chinese 17 17.  「細菌和殺死它們的抗生素之間的戰爭，就如同大國之間的軍備競爭，精益求
# 精，更相勝出，__________。」畫線處填入下列何者最能說明上述比喻的內涵？
# 104 Chinese 18 18.  袁宏道與友人書云：「人情必有所寄，然後能樂。故有以弈為寄，有以色為寄，
# 有以技為寄，有以文為寄。古之達人，高人一層，只是他情有所寄，不肯浮泛
# 虛度光景。」這段文字的主要涵義，與下列何者最接近？
# 104 Chinese 19 19.  下列文句，何者有語病？
# 104 Chinese 20 20.  民初某學者仍留著前朝的舊髮式，拖著一條辮子去北大授課，學生哄堂大笑，他
# 說：「我的辮子一剪就沒有了，但你們心中的辮子恐怕就沒有那麼容易剪掉了。」
# 他話中的涵義，與下列何者最接近？
# 104 Chinese 21 21.  「如果每個人都是特別的，那就沒有一個特別；如果每個人都得到一個獎
# 杯，獎杯就變得毫無意義。生活最甜美的樂趣，在於承認自己並不特別。」
# 這段文字的涵義，與下列何者最接近？
# 104 Chinese 22 22.  下列文句，何者用字完全正確？
# 104 Chinese 23 23.  「書，飢讀之以當肉；寒讀之以當裘；孤寂而讀之，以當友朋；幽憂而讀之，
# 以當金石琴瑟也。」這句話的涵義，與下列何者最接近？
# 104 Chinese 24 24.  白居易〈題山石榴花〉：「一叢千朵壓闌干，剪碎紅綃卻作團。風嫋舞腰香不盡，
# 露銷妝臉淚新乾。薔薇帶刺攀應懶，菡萏  生泥玩亦難。爭及  此花檐戶下，任人
# 1  2
# 採弄盡人看。」下列關於這首詩的說明，何者錯誤？
# 104 Chinese 25 25.  「如果有人認為文學是不著塵色的白裳，那是因為他遺忘了『現實』這一件緇衣。
# 崇拜詩聖杜甫的人，不見得讀得懂『杜詩』，但我們不難想像，當杜甫自外訪
# 友歸來，一進門問他老妻第一句話，也許是：『尚有油鹽否？
# 104 Chinese 26 26.  下列文句「」中的字詞，何者意義前後相同？
# 104 Chinese 27 27.  「余猶及見老儒先生，自言其少時，欲求《史記》、《漢書》而不可得，幸而得
# 之，皆手自書，日夜誦讀，惟恐不及。近歲市人轉相摹刻諸子百家之書，日傳萬
# 紙，學者之於書，多且易致如此，其文詞學術，當倍蓰  於昔人，而後生科舉之
# 1
# 士皆束書不觀，游談無根，此又何也？
# 104 Chinese 28 28.  下列文句「」中的成語，何者使用最恰當？
# 104 Chinese 29 29.
# 有盜年羹堯大將軍坐騎者，為岳鍾琦部所執，將科以刑。年知之即索
# 此人，__________。年因語岳曰：「此人敢盜余坐騎，膽量可知，故吾宥其
# 罪，用其所長，料必能達成此一使命也。」其識人、推恩也，悉類此。
# 根據文意脈絡判斷，畫線處應填入下列何者最恰當？
# 104 Chinese 31 31.  「世人以竹、木、牙、骨之類為『叫子』，置人喉中吹之，能作人言，謂之『嗓
# 叫子』。嘗有病瘖  者，為人所誣，煩冤無以自言。聽訟者試取叫子，令嗓之，
# 1
# 作聲如傀儡子  ，粗能辨其一二，其冤獲伸。此亦可記也。」根據這段文字，下
# 2
# 列有關「叫子」的敘述，何者無法明確得知？
# 104 Chinese 32 32.
# 相較於廣大的平民百姓，政務官、事務官、民意代表、媒體記者、知
# 識分子都是掌有權力的人。政務官負責政策的擘劃，事務官負責政策的執
# 行，民意代表負責審查，媒體記者負責監督，知識分子用知識和筆做時
# 代的眼光。細究之下，每一種權力都很可怕，它可以興邦，可以覆邦，影
# 響這一代人的此刻，下一代人的未來。掌權的人對自己手中所握有的權
# 力——權  力的性質、權力的界限、權力的責任，是否深思過呢？
# 104 Chinese 33 33.  以下是小臻在國文課所做的筆記，一時大意寫錯一處。筆記中的錯處應是下列
# 何者？
# 104 Chinese 34 34.  根據本文，「我相信對那些有慧根的人，這幾個字也就夠了。留一點餘味讓人
# 咀嚼體會，豈不更好？
# 104 Chinese 35 35.  下列何者最可能是本文所要傳達的人生態度？
# 104 Chinese 36 36.  下列何者最可能是作者說自己是「今之古人」的原因？
# 104 Chinese 37 37.  本文的主要內容，最可能是下列何者？
# 104 Chinese 38 38.  下列詩句的說明，何者正確？
# 104 Chinese 39 39.  關於本詩的寫作手法，下列敘述何者正確？
# 104 Chinese 40 40.  根據本文，關於雪山山脈的敘述，下列何者錯誤？
# 104 Chinese 41 41.  根據本文，下列關於淡水河水域的敘述，何者正確？
# 104 Chinese 42 42.  關於本文的寫作手法，下列敘述何者正確？
# 104 Chinese 43 43.  關於本文所述的「知縣」一職，下列說明何者正確？
# 104 Chinese 44 44.  根據本文，下列何人最符合遴選資格？
# 104 Chinese 45 45.  根據本文，景公的作為最適合以下列何者來形容？
# 104 Chinese 46 46.  本文呈現了晏子在政治上的哪一種智慧？
# 104 Chinese 47 47.  下列文句「」中語詞的意義，何者說明正確？
# 104 Chinese 48 48.  根據本文，關於賈堅與荀羨攻守的過程，下列敘述何者正確？
# done
# 104_English
# 14
# []
# done
# 104_Math
# 11
# ['1.  算式 (−1 ) × (−3 ) ×   之值為何？', '2.  已知直線 L 的方程式為 x = 3，直線 M 的方程式為 y = −2，判斷下列何者為\n直線 L、直線 M 畫在坐標平面上的圖形？', '3.  下列各選項中的盒狀圖分別呈現出某班四次小考數學成績的分布情形，\n       哪一個盒狀圖呈現的資料其四分位距最大？', '4.  算式 (−3)4 − 72 −   之值為何？', '5.  如圖(一)，  AB 為圓 O 的直徑，  BC 為圓 O 的 C\n一弦， 自 O 點作 BC 的垂線， 且交 BC 於 D 點。\nD\n若 AB = 16，  BC = 12，則 △OBD 的面積為何？', '6.  計算多項式 −2x (3x − 2)2 + 3除以 3x − 2 後，  所得商式與餘式兩者之和為何？', '7.  將圖 ( 二 ) 的正四角錐 ABCDE 沿著其中的四個邊剪開後，  形成的展開圖為\n圖 ( 三 )。判斷下列哪一個選項中的四個邊可為此四個邊？', '8.  下列哪一個選項中的等式不成立？', '9.  圖 ( 四 ) 為某餐廳的價目表，今日每份餐點價格均為價目表價格的九折。\n若恂恂今日在此餐廳點了橙汁雞丁飯後想再點第二份餐點，且兩份餐點的\n總花費不超過 200 元，則她的第二份餐點最多有幾種選擇？', '10.  如圖(五)，  AB 切圓 O  於 B 點，  AC 切圓 O  於 \n1 2\nC 點，  BC 分別交圓 O 、  圓 O 於 D、  E 兩點。若 \n1 2 \n∠BO D = 40°， ∠CO E = 60°，則 ∠A 的度數為\n1 2\n何？', '11.  圖(六)是 P 、  P 、  ......、 P 十個點在圓上的位置圖，\n1 2 10\n且此十點將圓周分成十等分。今小玉連接 P P 、 P P 、 \n1 2 1 10\nP P 、  P P 、  P P ， 判斷小玉再連接下列哪一條線段\n9 10 5 6 6 7\n後，所形成的圖形不是線對稱圖形？', '12.  怡君手上有 24 張卡片，其中 12 張卡片被畫上 O 記號，另外 12 張卡片被\n畫上 X 記號。圖 ( 七 ) 表示怡君從手上拿出 6 張卡片放在桌面的情形，且\n她打算從手上剩下的卡片中抽出一張卡片。若怡君手上剩下的每張卡片被\n抽出的機會相等，則她抽出 O 記號卡片的機率為何？', '13.  已知甲、乙為兩把不同刻度的直尺，且同一把直尺上的刻度之間距離相等，\n耀軒將此兩把直尺緊貼，並將兩直尺上的刻度 0 彼此對準後，發現甲尺的\n刻度 36 會對準乙尺的刻度 48，如圖 ( 八 ) 所示。若今將甲尺向右平移且\n平移過程中兩把直尺維持緊貼，使得甲尺的刻度 0 會對準乙尺的刻度 4，\n如圖 ( 九 ) 所示，則此時甲尺的刻度 21 會對準乙尺的哪一個刻度？', '14.  判斷一元二次方程式 x2 − 8x − a = 0 中的 a 為下列哪一個數時，可使得此\n方程式的兩根均為整數？', '15.  如圖 ( 十 )，坐標平面上有 A(0,a)、  B(−9,0) 、  \nC (10,0) 三點，其中 a > 0。若 ∠BAC = 95°，則 \n△ABC 的外心在第幾象限？', '16.  判斷下列各式的值，何者最大？', '17.  已知 A 地在 B 地的西方，且有一以 A、  B 兩地為端點的東西向直線道路，其\n全長為 400 公里。今在此道路上距離 A 地 12 公里處設置第一個看板，之後每\n往東 27 公里就設置一個看板，如圖(十一)所示。若某車從此道路上距離 A 地 \n19 公里處出發，往東直行320 公里後才停止，則此車在停止前經過的最後一個\n看板距離 A 地多少公里？', '18.  如圖(十二)， △ABC 中，  BC > AB > AC。  甲、乙兩人想在 BC 上取一點P ，\n         使得 ∠APC = 2∠ABC，其作法如下：\n(甲) 作 AB 的中垂線，交 BC 於 P 點，則 P 即為所求\n(乙)以 B 為圓心，  AB 長為半徑畫弧， 交 BC 於 P 點，\n             則 P 即為所求\n對於兩人的作法，下列判斷何者正確？', '19.  圖 ( 十三 ) 為甲、乙、丙三根筆直的木棍平行擺放在地面上的情形。已知乙\n有一部分只與甲重疊，其餘部分只與丙重疊，甲沒有與乙重疊的部分的長度\n為 1 公尺，丙沒有與乙重疊的部分的長度為 2 公尺。若乙的長度最長且甲、\n乙的長度相差 x 公尺，乙、丙的長度相差 y 公尺，則乙的長度為多少公尺？', '20.  如圖(十四)，  △ABC 、  △ADE 中，  C、  D 兩點分別在 \nAE、  AB 上，  BC 與 DE 相交於 F 點。若 BD = CD = CE ，  \n∠ADC + ∠ACD = 114°，   則 ∠DFC 的度數為何？', '22.  已知甲校原有 1016 人，乙校原有 1028 人，寒假期間甲、乙兩校人數變動的\n原因只有轉出與轉入兩種，且轉出的人數比為 1 : 3，轉入的人數比也為 1 : 3。\n若寒假結束開學時甲、乙兩校人數相同，則乙校開學時的人數與原有的人數\n相差多少？', '23.  圖 ( 十五 ) 為兩正方形 ABCD、  BEFG 和 A D\n     矩形 DGHI 的位置圖， 其中 G 、  F 兩點\nI\n        分別在 BC、  EH 上。 若 AB  =  5，   BG  =  3，  \nG\n            則 △GFH 的面積為何？', '24.  將甲、乙、丙三個正分數化為最簡分數後，其分子分別為 6、  15、  10 ，\n        其分母的最小公倍數為 360。判斷甲、乙、丙三數的大小關係為何？', '25.  圖 ( 十六 ) 的灰色小三角形為三個全等大三角形的重疊處，且三個大三角形各\n扣掉灰色小三角形後分別為甲、乙、丙三個梯形。若圖中標示的 ∠1 為 58°， \n∠2 為 62°，  ∠3 為 60°，則關於甲、乙、丙三梯形的高的大小關係，下列敘述\n何者正確？', '1.  大冠買了一包宣紙練習書法，每星期一寫 1 張，每星期二寫 2 張，每星期三\n寫 3 張，  每星期四寫 4 張，  每星期五寫 5 張，  每星期六寫 6 張，  每星期日寫 \n7 張。若大冠從某年的 5 月 1 日開始練習，到 5 月 30 日練習完後累積寫完的\n宣紙總數已超過 120 張，則 5 月 30 日可能為星期幾？']
# 104 Math 1 1.  算式 (−1 ) × (−3 ) ×   之值為何？
# 104 Math 2 2.  已知直線 L 的方程式為 x = 3，直線 M 的方程式為 y = −2，判斷下列何者為
# 直線 L、直線 M 畫在坐標平面上的圖形？
# 104 Math 3 3.  下列各選項中的盒狀圖分別呈現出某班四次小考數學成績的分布情形，
#        哪一個盒狀圖呈現的資料其四分位距最大？
# 104 Math 4 4.  算式 (−3)4 − 72 −   之值為何？
# 104 Math 5 5.  如圖(一)，  AB 為圓 O 的直徑，  BC 為圓 O 的 C
# 一弦， 自 O 點作 BC 的垂線， 且交 BC 於 D 點。
# D
# 若 AB = 16，  BC = 12，則 △OBD 的面積為何？
# 104 Math 6 6.  計算多項式 −2x (3x − 2)2 + 3除以 3x − 2 後，  所得商式與餘式兩者之和為何？
# 104 Math 7 7.  將圖 ( 二 ) 的正四角錐 ABCDE 沿著其中的四個邊剪開後，  形成的展開圖為
# 圖 ( 三 )。判斷下列哪一個選項中的四個邊可為此四個邊？
# 104 Math 8 8.  下列哪一個選項中的等式不成立？
# 104 Math 9 9.  圖 ( 四 ) 為某餐廳的價目表，今日每份餐點價格均為價目表價格的九折。
# 若恂恂今日在此餐廳點了橙汁雞丁飯後想再點第二份餐點，且兩份餐點的
# 總花費不超過 200 元，則她的第二份餐點最多有幾種選擇？
# 104 Math 10 10.  如圖(五)，  AB 切圓 O  於 B 點，  AC 切圓 O  於
# 1 2
# C 點，  BC 分別交圓 O 、  圓 O 於 D、  E 兩點。若
# 1 2
# ∠BO D = 40°， ∠CO E = 60°，則 ∠A 的度數為
# 1 2
# 何？
# 104 Math 11 11.  圖(六)是 P 、  P 、  ......、 P 十個點在圓上的位置圖，
# 1 2 10
# 且此十點將圓周分成十等分。今小玉連接 P P 、 P P 、
# 1 2 1 10
# P P 、  P P 、  P P ， 判斷小玉再連接下列哪一條線段
# 9 10 5 6 6 7
# 後，所形成的圖形不是線對稱圖形？
# 104 Math 12 12.  怡君手上有 24 張卡片，其中 12 張卡片被畫上 O 記號，另外 12 張卡片被
# 畫上 X 記號。圖 ( 七 ) 表示怡君從手上拿出 6 張卡片放在桌面的情形，且
# 她打算從手上剩下的卡片中抽出一張卡片。若怡君手上剩下的每張卡片被
# 抽出的機會相等，則她抽出 O 記號卡片的機率為何？
# 104 Math 13 13.  已知甲、乙為兩把不同刻度的直尺，且同一把直尺上的刻度之間距離相等，
# 耀軒將此兩把直尺緊貼，並將兩直尺上的刻度 0 彼此對準後，發現甲尺的
# 刻度 36 會對準乙尺的刻度 48，如圖 ( 八 ) 所示。若今將甲尺向右平移且
# 平移過程中兩把直尺維持緊貼，使得甲尺的刻度 0 會對準乙尺的刻度 4，
# 如圖 ( 九 ) 所示，則此時甲尺的刻度 21 會對準乙尺的哪一個刻度？
# 104 Math 14 14.  判斷一元二次方程式 x2 − 8x − a = 0 中的 a 為下列哪一個數時，可使得此
# 方程式的兩根均為整數？
# 104 Math 15 15.  如圖 ( 十 )，坐標平面上有 A(0,a)、  B(−9,0) 、
# C (10,0) 三點，其中 a > 0。若 ∠BAC = 95°，則
# △ABC 的外心在第幾象限？
# 104 Math 16 16.  判斷下列各式的值，何者最大？
# 104 Math 17 17.  已知 A 地在 B 地的西方，且有一以 A、  B 兩地為端點的東西向直線道路，其
# 全長為 400 公里。今在此道路上距離 A 地 12 公里處設置第一個看板，之後每
# 往東 27 公里就設置一個看板，如圖(十一)所示。若某車從此道路上距離 A 地
# 19 公里處出發，往東直行320 公里後才停止，則此車在停止前經過的最後一個
# 看板距離 A 地多少公里？
# 104 Math 18 18.  如圖(十二)， △ABC 中，  BC > AB > AC。  甲、乙兩人想在 BC 上取一點P ，
#          使得 ∠APC = 2∠ABC，其作法如下：
# (甲) 作 AB 的中垂線，交 BC 於 P 點，則 P 即為所求
# (乙)以 B 為圓心，  AB 長為半徑畫弧， 交 BC 於 P 點，
#              則 P 即為所求
# 對於兩人的作法，下列判斷何者正確？
# 104 Math 19 19.  圖 ( 十三 ) 為甲、乙、丙三根筆直的木棍平行擺放在地面上的情形。已知乙
# 有一部分只與甲重疊，其餘部分只與丙重疊，甲沒有與乙重疊的部分的長度
# 為 1 公尺，丙沒有與乙重疊的部分的長度為 2 公尺。若乙的長度最長且甲、
# 乙的長度相差 x 公尺，乙、丙的長度相差 y 公尺，則乙的長度為多少公尺？
# 104 Math 20 20.  如圖(十四)，  △ABC 、  △ADE 中，  C、  D 兩點分別在
# AE、  AB 上，  BC 與 DE 相交於 F 點。若 BD = CD = CE ，
# ∠ADC + ∠ACD = 114°，   則 ∠DFC 的度數為何？
# 104 Math 22 22.  已知甲校原有 1016 人，乙校原有 1028 人，寒假期間甲、乙兩校人數變動的
# 原因只有轉出與轉入兩種，且轉出的人數比為 1 : 3，轉入的人數比也為 1 : 3。
# 若寒假結束開學時甲、乙兩校人數相同，則乙校開學時的人數與原有的人數
# 相差多少？
# 104 Math 23 23.  圖 ( 十五 ) 為兩正方形 ABCD、  BEFG 和 A D
#      矩形 DGHI 的位置圖， 其中 G 、  F 兩點
# I
#         分別在 BC、  EH 上。 若 AB  =  5，   BG  =  3，
# G
#             則 △GFH 的面積為何？
# 104 Math 24 24.  將甲、乙、丙三個正分數化為最簡分數後，其分子分別為 6、  15、  10 ，
#         其分母的最小公倍數為 360。判斷甲、乙、丙三數的大小關係為何？
# 104 Math 25 25.  圖 ( 十六 ) 的灰色小三角形為三個全等大三角形的重疊處，且三個大三角形各
# 扣掉灰色小三角形後分別為甲、乙、丙三個梯形。若圖中標示的 ∠1 為 58°，
# ∠2 為 62°，  ∠3 為 60°，則關於甲、乙、丙三梯形的高的大小關係，下列敘述
# 何者正確？
# 104 Math 1 1.  大冠買了一包宣紙練習書法，每星期一寫 1 張，每星期二寫 2 張，每星期三
# 寫 3 張，  每星期四寫 4 張，  每星期五寫 5 張，  每星期六寫 6 張，  每星期日寫
# 7 張。若大冠從某年的 5 月 1 日開始練習，到 5 月 30 日練習完後累積寫完的
# 宣紙總數已超過 120 張，則 5 月 30 日可能為星期幾？
# done
# 104_Society
# 14
# ['1.  圖(一)為臺灣1980年、2010年及推估2040年的扶養比示意圖，依據年代先後順\n序排列應為下列何者？', '2.  根據聯合國《海洋法公約》規定，各國擁有在其經濟海域內資源的使用權。臺灣\n因四面環海，島嶼眾多，擁有廣大的經濟海域，但因與鄰近國家的經濟海域重\n疊，經常有漁業上的糾紛。上文所述的鄰近國家不包含下列何者？', '3.  圖(二)為颱風、梅雨、寒害、乾旱在臺灣西 (cid:20) (cid:21) (cid:22) (cid:23) (cid:24) (cid:25) (cid:26) (cid:27) (cid:28) (cid:20)(cid:19) (cid:20)(cid:20)(cid:20)(cid:21)\n(cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766)\n南部主要發生的月分，下列配對何者正確？', '4.  「新加坡的土地面積雖然不大，但因具有某項優越的條件，加上政府政策的\n指導，成功地讓新加坡的煉油產業快速發展，現已成為世界第三大煉油中\n心。」文中所述的優越條件應是指下列何者？', '5.  圖(三)顯示歷年2月分北極海冰範圍變化情 ((cid:1325)17.0\n(cid:4068)\n形，該變化趨勢與下列同時期何者的變化趨\n(cid:1139)16.5\n勢最為相似？', '6.  圖(四)為某雜誌上刊載的紀念戳章及其簡介，根據內\n容判斷，此紀念章最可能是描繪下列何時臺灣的景\n象？', '7.  以下是一段十七世紀的文獻記載：「西班牙人每年向該地\n的已婚原住民課徵二隻雞和三甘當米的稅，原住民感到無\n法忍受，所以襲擊該地的西班牙城堡，殺了三十個西班牙\n(cid:908)\n人。」此段記載最可能是描繪圖(五)中何處的情況？', '8.  十六世紀時，馬丁路德批判羅馬教會，揭開宗教改革的序幕。下列資料中何者\n最可能是馬丁路德的主張？', '9.  某書提及：「清廷想收回民間集資興建鐵路的權利，所以針對民間已投資者\n提出補償：在湖南、湖北，投資金額全數償還；在廣東，僅償還 60%，其餘\n40%由政府股票支付；在四川，政府僅發給股票。這種處置引起四川士紳激\n憤，朝廷為控制騷亂，將部分湖北軍隊調往四川。」上述情況最可能為下列\n何者的發生提供了機會？', '10.  圖(六)描繪中國某一朝代的官員正在接待來訪\n使節的情況，根據圖片內容判斷，此朝代最可\n能是下列何者？', '11.  公民老師在課堂上說明關於「價值觀念變遷」的主題，並請四位同學舉出適\n當的例子加以說明。下列哪一位同學舉出的例子，最符合上述主題？', '12.  表(一)是大榮家一年來理財投資結果的分析 表(一)\n表。根據表中內容判斷，大榮家所選擇的各 投入金額 獲利金額\n投資工具\n項投資工具中，何者的投資報酬率最高？', '13.  發生刑事案件時，偵查人員蒐集、鑑定相關證據，並研判嫌疑人的心態、動\n機等，以呈現犯罪事實，其目的在提供下列何人作為「判決」的依據？', '14.  過去大家總認為「法不入家門」，但近年來家庭暴力問題逐漸受到重視，因\n此政府制定《家庭暴力防治法》，以處理相關問題。下列何者屬於上述法規\n處理此類問題的作法？', '15.  右列是小諭舉例說明某一概念的部分內容，\n\uf097 皮皮辦理簽證，利用假期到國 \n根據內容判斷，這應是在探討《憲法》中的\n哪一項人民基本權利？', '16.  圖(七)為臺灣某一縣市的海岸地形特徵 N\n示意圖，根據圖中資訊判斷，最有可能\n(cid:12470)(cid:11220)(cid:11179)(cid:10111) (cid:18112)(cid:18409)(cid:9693)(cid:23464) (cid:11111)(cid:18097)(cid:15413)(cid:11126)\n是顯示下列哪一縣市的海岸地形特徵？', '17.  近年來，鳳梨酥成為國人及外國遊客\n(cid:18668)(cid:14283)(cid:433)(cid:12895)(cid:13300) (cid:24329)(cid:24255) (cid:22459)(cid:7706)(cid:433)(cid:8643)(cid:22427) (cid:24949)(cid:9196)\n喜愛的伴手禮之一，產值逐年上升。 (cid:1176) (cid:908) (cid:1063) (cid:909)\n圖(八)為鳳梨酥產銷過程的示意圖， 圖(八)\n甲、乙、丙、丁哪些屬於第三級產業？', '18.  某位旅行家從北非乾燥地區出發，向北經地中\n海到達北歐，圖(九)是他記錄途中民宅常見的\n(cid:7447)\n窗戶形式。在他的旅途中依序記錄的窗戶形式\n應為下列何者？', '19.  圖(十)為中國某一氣候資料的等值線分布圖，\n圖中甲＜乙＜丙＜丁，則該氣候資料應為下列\n何者？', '20.  圖(十一)是北美洲沿35°N的地形剖面圖。圖中甲、乙、丙、丁何處的年降水\n量最少？', '21.  一份歷史文告寫道：「自宋朝覆亡，北方外族入主中原，百年不到，天下大亂。\n我本是平民，被眾人推舉，率軍攻占金陵(今南京)，再北上驅逐胡虜。色目等雖為\n異族，但若衷心歸順，仍是中華子民。」以上敘述與下列哪一史事關係最密切？', '22.  圖(十二)為臺灣\n某一史前文化遺\n址的圖片，根據\n其內容判斷，此\n一文化應為下列\n何者？', '23.  圖(十三)呈現某時期中華民國政府對於一本辭典的審查結\n果，根據圖片內容判斷，此辭典最可能是在下列何時接受\n政府單位的審查？', '24.  圖(十四)是歷史上某人宣誓的內容，該宣誓和下列何者最有關係？', '25.  右列是某次美國外交聲明的概要，根據\n我國政府希望各國在中國的商業\n內容判斷，美國為何發表此一聲明？', '26.  據報載，我國某縣的財政狀況長期入不敷出，導致當地政府的財政問題日益\n嚴重，恐將出現延遲發放基層公務人員薪水的情形。為了解決上述問題，下\n列何者最可能是該縣政府依法採行的方法？', '27.  某黨主席在一場選舉活動中，為該黨候選人李大同拉票的發言內容如下：\n「李大同已多次連任，具有豐富的經驗，相信他一定能為大家好好的監督政\n府，請各位選民繼續給他連任的機會。」李大同所參選的公職人員最可能是\n下列何者？', '28.  右列是阿平上課報告時所舉的例子，\n汽車駕駛人於開車時，使用手持式\n根據其內容判斷，下列何者最可能是\n行動電話進行撥接或通話者，處新\n該報告的主題？', '29.  小英和阿泉一起編製竹筐和斗笠，依比較利益法則進行分 表(二)\n工，阿泉被分配去製作竹筐，表(二)是他們每小時所能製作 竹筐 斗笠\n數量的部分數據。根據上述內容判斷，下列敘述何者正確？', '30.  新聞節目製作了藝人林小花的專題報導，而小花在看完報導後認為內容有\n誤，造成她的困擾。律師告訴小花，其實她有權要求該節目給予答辯之機\n會，且電視臺不得拒絕。下列何者最符合上述內容的意涵？', '31.  在古代，由於沒有電話和無線電等通訊設\n備，烽火臺成為傳遞軍情的最好設施之一，\n傳遞的方法是白天燃煙，夜間舉火。為使軍\n200\n情能快速傳遞，烽火臺通常設置在視野極佳\n的位置。圖(十五)中甲、乙、丙、丁哪一地 400 300 200 00 m\n點最適合設置烽火臺？', '32.  近年來，中國許多內陸的民工不願再到沿海地區工作，反而留在家鄉就業，\n使沿海地區爆發嚴重的「缺工潮」，沿海工廠只好不斷放寬條件限制，或以\n其他誘因來吸引員工。下列何者最可能是造成上述缺工潮的原因？', '33.  希臘的海岸線曲折、多海灣，這是因陸地丘陵延伸至海岸，受海面相對上升的\n影響，沿海谷地被海水淹沒，使得各處都有深入內陸的海灣。依上文所描述的\n海岸特性，下列何處的海岸類型與希臘最為相似？', '34.  圖(十六)呈現2000年某一地理現象在不同\n60°N\n緯度的分布差異。已知縱坐標為緯度， 30°N\n橫坐標代表該現象的數據。根據該現象 0°\n30°S\n在不同緯度的數據大小判斷，此一地理\n60°S\n現象最可能是指下列何者？', '35.  德國由於生育率低，人口結構老化，總 表(三)\n人口數多年呈現負成長。2011年，該國 年度\n2010 年 2011 年\n人口資料\n總人口數較前一年成長0.1%，是近年\n來首度正成長。表(三)是該國2010年和 總人口數 8170.8 8180.0\n2011年的部分人口資料，根據表中資料 新生兒人口數     67.8     66.3\n推論，下列何者最可能是德國該年總人 死亡人口數     85.8     85.2\n口數增加的主要原因？', '36.  圖(十七)中甲、乙、丙三張照片，分別與某戰爭中的三個重要事件有關，若依這\n些事件發生的時間先後順序排列，下列何者正確？', '37.  歷史學者曾指出：「西周的封建，乃是一種侵略性\n的武裝移民與軍事占領。」上述朝代的封建擴張，\n主要是向圖(十八)中哪一方向？', '38.  表(四)是歷史上某人在臺灣旅遊的部分行 ...
# 104 Society 1 1.  圖(一)為臺灣1980年、2010年及推估2040年的扶養比示意圖，依據年代先後順
# 序排列應為下列何者？
# 104 Society 2 2.  根據聯合國《海洋法公約》規定，各國擁有在其經濟海域內資源的使用權。臺灣
# 因四面環海，島嶼眾多，擁有廣大的經濟海域，但因與鄰近國家的經濟海域重
# 疊，經常有漁業上的糾紛。上文所述的鄰近國家不包含下列何者？
# 104 Society 3 3.  圖(二)為颱風、梅雨、寒害、乾旱在臺灣西 (cid:20) (cid:21) (cid:22) (cid:23) (cid:24) (cid:25) (cid:26) (cid:27) (cid:28) (cid:20)(cid:19) (cid:20)(cid:20)(cid:20)(cid:21)
# (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766) (cid:13766)
# 南部主要發生的月分，下列配對何者正確？
# 104 Society 4 4.  「新加坡的土地面積雖然不大，但因具有某項優越的條件，加上政府政策的
# 指導，成功地讓新加坡的煉油產業快速發展，現已成為世界第三大煉油中
# 心。」文中所述的優越條件應是指下列何者？
# 104 Society 5 5.  圖(三)顯示歷年2月分北極海冰範圍變化情 ((cid:1325)17.0
# (cid:4068)
# 形，該變化趨勢與下列同時期何者的變化趨
# (cid:1139)16.5
# 勢最為相似？
# 104 Society 6 6.  圖(四)為某雜誌上刊載的紀念戳章及其簡介，根據內
# 容判斷，此紀念章最可能是描繪下列何時臺灣的景
# 象？
# 104 Society 7 7.  以下是一段十七世紀的文獻記載：「西班牙人每年向該地
# 的已婚原住民課徵二隻雞和三甘當米的稅，原住民感到無
# 法忍受，所以襲擊該地的西班牙城堡，殺了三十個西班牙
# (cid:908)
# 人。」此段記載最可能是描繪圖(五)中何處的情況？
# 104 Society 8 8.  十六世紀時，馬丁路德批判羅馬教會，揭開宗教改革的序幕。下列資料中何者
# 最可能是馬丁路德的主張？
# 104 Society 9 9.  某書提及：「清廷想收回民間集資興建鐵路的權利，所以針對民間已投資者
# 提出補償：在湖南、湖北，投資金額全數償還；在廣東，僅償還 60%，其餘
# 40%由政府股票支付；在四川，政府僅發給股票。這種處置引起四川士紳激
# 憤，朝廷為控制騷亂，將部分湖北軍隊調往四川。」上述情況最可能為下列
# 何者的發生提供了機會？
# 104 Society 10 10.  圖(六)描繪中國某一朝代的官員正在接待來訪
# 使節的情況，根據圖片內容判斷，此朝代最可
# 能是下列何者？
# 104 Society 11 11.  公民老師在課堂上說明關於「價值觀念變遷」的主題，並請四位同學舉出適
# 當的例子加以說明。下列哪一位同學舉出的例子，最符合上述主題？
# 104 Society 12 12.  表(一)是大榮家一年來理財投資結果的分析 表(一)
# 表。根據表中內容判斷，大榮家所選擇的各 投入金額 獲利金額
# 投資工具
# 項投資工具中，何者的投資報酬率最高？
# 104 Society 13 13.  發生刑事案件時，偵查人員蒐集、鑑定相關證據，並研判嫌疑人的心態、動
# 機等，以呈現犯罪事實，其目的在提供下列何人作為「判決」的依據？
# 104 Society 14 14.  過去大家總認為「法不入家門」，但近年來家庭暴力問題逐漸受到重視，因
# 此政府制定《家庭暴力防治法》，以處理相關問題。下列何者屬於上述法規
# 處理此類問題的作法？
# 104 Society 15 15.  右列是小諭舉例說明某一概念的部分內容，
#  皮皮辦理簽證，利用假期到國
# 根據內容判斷，這應是在探討《憲法》中的
# 哪一項人民基本權利？
# 104 Society 16 16.  圖(七)為臺灣某一縣市的海岸地形特徵 N
# 示意圖，根據圖中資訊判斷，最有可能
# (cid:12470)(cid:11220)(cid:11179)(cid:10111) (cid:18112)(cid:18409)(cid:9693)(cid:23464) (cid:11111)(cid:18097)(cid:15413)(cid:11126)
# 是顯示下列哪一縣市的海岸地形特徵？
# 104 Society 17 17.  近年來，鳳梨酥成為國人及外國遊客
# (cid:18668)(cid:14283)(cid:433)(cid:12895)(cid:13300) (cid:24329)(cid:24255) (cid:22459)(cid:7706)(cid:433)(cid:8643)(cid:22427) (cid:24949)(cid:9196)
# 喜愛的伴手禮之一，產值逐年上升。 (cid:1176) (cid:908) (cid:1063) (cid:909)
# 圖(八)為鳳梨酥產銷過程的示意圖， 圖(八)
# 甲、乙、丙、丁哪些屬於第三級產業？
# 104 Society 18 18.  某位旅行家從北非乾燥地區出發，向北經地中
# 海到達北歐，圖(九)是他記錄途中民宅常見的
# (cid:7447)
# 窗戶形式。在他的旅途中依序記錄的窗戶形式
# 應為下列何者？
# 104 Society 19 19.  圖(十)為中國某一氣候資料的等值線分布圖，
# 圖中甲＜乙＜丙＜丁，則該氣候資料應為下列
# 何者？
# 104 Society 20 20.  圖(十一)是北美洲沿35°N的地形剖面圖。圖中甲、乙、丙、丁何處的年降水
# 量最少？
# 104 Society 21 21.  一份歷史文告寫道：「自宋朝覆亡，北方外族入主中原，百年不到，天下大亂。
# 我本是平民，被眾人推舉，率軍攻占金陵(今南京)，再北上驅逐胡虜。色目等雖為
# 異族，但若衷心歸順，仍是中華子民。」以上敘述與下列哪一史事關係最密切？
# 104 Society 22 22.  圖(十二)為臺灣
# 某一史前文化遺
# 址的圖片，根據
# 其內容判斷，此
# 一文化應為下列
# 何者？
# 104 Society 23 23.  圖(十三)呈現某時期中華民國政府對於一本辭典的審查結
# 果，根據圖片內容判斷，此辭典最可能是在下列何時接受
# 政府單位的審查？
# 104 Society 24 24.  圖(十四)是歷史上某人宣誓的內容，該宣誓和下列何者最有關係？
# 104 Society 25 25.  右列是某次美國外交聲明的概要，根據
# 我國政府希望各國在中國的商業
# 內容判斷，美國為何發表此一聲明？
# 104 Society 26 26.  據報載，我國某縣的財政狀況長期入不敷出，導致當地政府的財政問題日益
# 嚴重，恐將出現延遲發放基層公務人員薪水的情形。為了解決上述問題，下
# 列何者最可能是該縣政府依法採行的方法？
# 104 Society 27 27.  某黨主席在一場選舉活動中，為該黨候選人李大同拉票的發言內容如下：
# 「李大同已多次連任，具有豐富的經驗，相信他一定能為大家好好的監督政
# 府，請各位選民繼續給他連任的機會。」李大同所參選的公職人員最可能是
# 下列何者？
# 104 Society 28 28.  右列是阿平上課報告時所舉的例子，
# 汽車駕駛人於開車時，使用手持式
# 根據其內容判斷，下列何者最可能是
# 行動電話進行撥接或通話者，處新
# 該報告的主題？
# 104 Society 29 29.  小英和阿泉一起編製竹筐和斗笠，依比較利益法則進行分 表(二)
# 工，阿泉被分配去製作竹筐，表(二)是他們每小時所能製作 竹筐 斗笠
# 數量的部分數據。根據上述內容判斷，下列敘述何者正確？
# 104 Society 30 30.  新聞節目製作了藝人林小花的專題報導，而小花在看完報導後認為內容有
# 誤，造成她的困擾。律師告訴小花，其實她有權要求該節目給予答辯之機
# 會，且電視臺不得拒絕。下列何者最符合上述內容的意涵？
# 104 Society 31 31.  在古代，由於沒有電話和無線電等通訊設
# 備，烽火臺成為傳遞軍情的最好設施之一，
# 傳遞的方法是白天燃煙，夜間舉火。為使軍
# 200
# 情能快速傳遞，烽火臺通常設置在視野極佳
# 的位置。圖(十五)中甲、乙、丙、丁哪一地 400 300 200 00 m
# 點最適合設置烽火臺？
# 104 Society 32 32.  近年來，中國許多內陸的民工不願再到沿海地區工作，反而留在家鄉就業，
# 使沿海地區爆發嚴重的「缺工潮」，沿海工廠只好不斷放寬條件限制，或以
# 其他誘因來吸引員工。下列何者最可能是造成上述缺工潮的原因？
# 104 Society 33 33.  希臘的海岸線曲折、多海灣，這是因陸地丘陵延伸至海岸，受海面相對上升的
# 影響，沿海谷地被海水淹沒，使得各處都有深入內陸的海灣。依上文所描述的
# 海岸特性，下列何處的海岸類型與希臘最為相似？
# 104 Society 34 34.  圖(十六)呈現2000年某一地理現象在不同
# 60°N
# 緯度的分布差異。已知縱坐標為緯度， 30°N
# 橫坐標代表該現象的數據。根據該現象 0°
# 30°S
# 在不同緯度的數據大小判斷，此一地理
# 60°S
# 現象最可能是指下列何者？
# 104 Society 35 35.  德國由於生育率低，人口結構老化，總 表(三)
# 人口數多年呈現負成長。2011年，該國 年度
# 2010 年 2011 年
# 人口資料
# 總人口數較前一年成長0.1%，是近年
# 來首度正成長。表(三)是該國2010年和 總人口數 8170.8 8180.0
# 2011年的部分人口資料，根據表中資料 新生兒人口數     67.8     66.3
# 推論，下列何者最可能是德國該年總人 死亡人口數     85.8     85.2
# 口數增加的主要原因？
# 104 Society 36 36.  圖(十七)中甲、乙、丙三張照片，分別與某戰爭中的三個重要事件有關，若依這
# 些事件發生的時間先後順序排列，下列何者正確？
# 104 Society 37 37.  歷史學者曾指出：「西周的封建，乃是一種侵略性
# 的武裝移民與軍事占領。」上述朝代的封建擴張，
# 主要是向圖(十八)中哪一方向？
# 104 Society 38 38.  表(四)是歷史上某人在臺灣旅遊的部分行 表(四)
# 程，依內容判斷，此人最可能是下列何 時間 地點 參觀行程
# 者？
# 104 Society 39 39.  圖(十九)呈現在1500年與1913年，某一洲的國家因政 70
# 治、軍事、經濟力量的轉變，所掌控的世界陸地面 60
# 積比例的變化。此一洲最可能是下列何者？
# 104 Society 40 40.  某國因強烈颶風侵襲，導致各地發生嚴重災情、民眾傷亡無數。若這樣的情
# 況發生在我國，而政府認為應發布緊急命令加以因應，下列何者是其生效的
# 必要條件之一？
# 104 Society 41 41.  圖(二十)是上公民課時使用的教
# (cid:22282)(cid:13309)(cid:22770)(cid:22749)
# (cid:15055)(cid:7497)(cid:14086)(cid:7604)
# 具，根據圖中的相對關係判斷， (cid:14086)(cid:7604)
# 該「權利救濟機關」應為下列何
# (cid:14792)(cid:14792)(cid:8423)(cid:8423)(cid:13327)(cid:13327)(cid:16029)(cid:16029)(cid:14621)(cid:14621)(cid:25754)(cid:25754)
# 者？
# 104 Society 42 42.  飯店業者常運用需求法則，針對不同時段 表(五)
# 的來客數量設定不同的價格，希望盡可能 時段 原本房價(元) 優惠後房價(元)
# 提高住房率。表(五)為某飯店原本房價及 甲 4000 2800
# 優惠後房價，根據表中資料判斷，若不考
# 乙 4000 2000
# 慮其他條件，下列何者最可能是該飯店推
# 丙 4000 3600
# 出優惠方案之前的住房情況？
# 104 Society 43 43.  圖(二十一)是依某店家招牌商品的市場供需狀況所繪
# 110
# 製的圖形，根據圖中訊息判斷，此項招牌商品在下
# 列四種定價時，何者為店家帶來的銷貨收入最高？
# 104 Society 44 44.  基於家庭倫理及優生學的考量，我國《民法》規定具有近親關係的血親及姻
# 親間不得結婚。根據上述內容判斷，下列何種組合若登記結婚，其婚姻最可
# 能是有效的？
# 104 Society 45 45.  從十六世紀哥白尼的「地球繞日說」，到十七世紀伽利略主張「太陽中心
# 說」、牛頓發表「萬有引力定律」，這些學說的提出，在歷史上最可能具有
# 下列何種意義？
# 104 Society 46 46.  新聞報導：「少子化問題日益嚴重，我國的自然增加率恐將成為負值，政府
# 已把此問題視為危及國家安全的國安議題，交由各部會擬定妥善的因應政
# 策。」上述內容最可能是在關切下列哪一項國家組成要素的變化？
# 104 Society 47 47.  公民老師為介紹歷史上某一重要事件所使用的簡圖，如圖(二十二)，其中甲、乙
# 最可能為下列何者？
# 104 Society 48 48.  18歲的小蔡買了新房子，並完成相關手續，父母知情後雖不同意，但買賣契
# 約仍然有效；19歲的雯雯買了昂貴的名牌包，但因某些原因，此交易行為無
# 效。根據上述內容判斷，文中二人的情形最不可能是下列何者？
# 104 Society 49 49.  圖(二十三)呈現某一歷史事
# 件前後，清朝治臺措施的差
# 異。從圖中內容判斷，此一
# 事件應是下列何者？
# 104 Society 50 50.  中國某電視臺舉辦旅遊路線設計比賽，其中有一
# 路線的行程安排如圖(二十四)所示。若要寫出呈
# (cid:16967)(cid:16967)(cid:25662)(cid:25662)(cid:25754)(cid:25754)
# 現該路線特色的介紹詞句，下列何者最合適？
# 104 Society 51 51.  2013年，巴西幣貶值，幣值創四年來低點，連帶影響該國的進出口貿易。若
# 其他條件不變的情況下，此幣值波動對巴西咖啡產業造成的影響，下列何者
# 正確？
# 104 Society 52 52.  圖(二十五)是某旅遊手冊的部分內
# 容，此手冊最可能是介紹圖(二十六)
# 中的何地？
# 104 Society 53 53.  假設身為監察委員的大佑，在某 表(六)
# 段期間看到媒體揭露的四則新聞 新聞 報導內容
# 報導，如表(六)所示。根據大佑的 民調顯示，民眾對於內閣官員的滿
# 甲
# 職權判斷，表中哪一則新聞的報 意度大幅下滑。
# 導對象，最可能被他提出彈劾？
# 104 Society 54 54.  崇明島是位於中國第一大河出海口的島嶼，大部分隸屬於上海市。在某一段時
# 期，由於居民在島嶼周邊圍河造田，加上該大河流域內其他地區的人為活動，
# 使得島嶼面積逐漸增加。下列哪項人為活動與上文描述的島嶼面積變化關連最
# 密切？
# 104 Society 55 55.  秧秧至某城市旅遊，發現此城市曾歷經亞歷山大帝國、羅馬帝國、阿拉伯帝國、
# 鄂圖曼土耳其帝國的統治。秧秧最可能至下列哪一城市旅遊？
# 104 Society 56 56.  上文所述社會動盪不安的年代，主要是指下列何者？
# 104 Society 57 57.  下列哪一組經緯度坐標，最接近上述內陸國家所在位置？
# 104 Society 58 58.  上述內陸國家境內的山區，應屬於下列哪一座山脈？
# 104 Society 59 59.  根據上述內容判斷，下列哪種社會變遷的趨勢最可能符合文中敘述？
# 104 Society 60 60.  文中所提及違法行為應受到的處罰，與下列何者所應負起的法律責任類型相同？
# 104 Society 61 61.  上文中美國國會通過的「法案」，最可能呈現下列哪一概念？
# 104 Society 62 62.  根據上文對中國的描述，當時中國最可能出現下列哪一景象？
# 104 Society 63 63.  上文所述的「老大哥」，最可能是下列何者？
# done
# 104_Nature
# 14
# ['1.   圖(一)是生物進行某種生理作用的示意圖，圖中箭頭 (cid:31)(cid:30)(cid:29)(cid:28)\n代表能量或物質在葉片中的進出，此生理作用最可\n(cid:30)(cid:25)\n能是下列何者？', '2.   小臻取石墨、硫、鋁和銀四種物質中的其中一個，來進行如圖(二)所示的二個\n實驗，根據實驗結果判斷，她最可能是取哪一個物質來進行實驗？', '3.   小樺突然想到海邊觀察星象，而去請教氣象專家。專家說現在天氣圖上本地\n是被標記為「L」的天氣系統籠罩，建議他改天再去。專家會做出如此建議，可\n能是當此天氣系統籠罩時，將會造成下列何種影響？', '4.   某人分別於甲、乙二區種植具有抗蟲基因的棉花及一般棉花，中間以道路相隔，\n如圖(三)所示。經過一段時間後，發現乙區的棉花也具有此抗蟲基因，產生此現\n象的原因，最可能是棉花的下列哪一構造傳播所造成？', '5.   若以箭頭方向表示電流方向，則下列選項中哪一個電路裝置表示的電流方向正\n確？', '6.   某地區樹林中棲息著一種蛾，依身體顏色可分成深色蛾和淺色蛾，其主要的天敵\n為鳥類。圖(四)為某段期間內深色蛾及淺色蛾數量變化的示意圖，圖中灰色部分標\n記為甲、乙兩時期。若依天擇說解釋甲或乙時期蛾的數量變化，下列何者最合理？', '7.   圖(五)為某古裝劇的一段對話，部分劇情雖為杜撰，但對話中所提到的內容符合\n科學原理。已知草灰水溶液為鹼性，根據對話內容，判斷圖中進行了何種類型\n的反應？', '8.   阿問以手施一大小為 F 的作用力，水平向東推木樁，木樁仍然立著不動，手受\n到木樁回推一個反作用力。關於其反作用力的作用情形，下列何者正確？', '9.   下列何者不是搬運作用的現象？', '10.   小琪要從圖(六)的甲、乙兩罐藥瓶中取出適量藥品進行實驗，根據\n藥品名稱判斷，最適合取用此兩種藥品的器材分別為下列何者？', '11.   有五個大小不同的實心金屬球，小莉分別將這些金屬球丟入水中，利用金屬球\n排開水的體積來量得這些金屬球的體積(V)，並以天平量測其質量(M)，最後將\n結果描繪如圖(七)。她發現圖上各點恰可連成一條直線，且此直線通過原點，則\n她提出下列哪一個說明來解釋此一現象最合適？', '12.   圖(八)為一則新聞報導的畫面與資訊，報導中指出：「一輛載運廢土的砂石車\n突然起火，消防人員灑水灌救，反而造成爆炸。原來是廢土中含有鋁粉，遇到\n熱水會激烈反應，甚至會爆炸。鋁為活性很大的物質……。」下列哪一類的元\n素碰到水會進行和上述鋁粉碰到熱水相似的反應？', '13.   下列關於溫室效應與全球暖化現象的說明，何者最為合理？', '14.   一條彈簧的上端固定於支架上，下端未吊掛物體時，彈簧的長度為 10 cm。在\n其下方吊掛一個質量未知的物體甲，彈簧的總長度變為 12 cm，接著在物體甲的\n下方，再加掛一個 60 g 的砝碼，則彈簧的總長度變為 15 cm。若移除物體甲與\n砝碼後，彈簧恢復原長，則物體甲的質量應為多少？', '15.   如圖(九)所示，甲、乙為一臺複式顯微鏡上兩種不同倍率\n的物鏡。小閔使用此顯微鏡觀察口腔皮膜細胞，他按照\n使用顯微鏡的標準步驟依序開始操作，有關物鏡的轉換\n及視野亮度的變化，下列敘述何者最合理？', '16.   「地球到太陽的平均距離」為 1 天文單位。下列敘述中的距離，何者大於 \n1 天文單位？', '17.   如圖(十)所示，在一個槓桿兩側分別以細繩吊掛臘肉與烤鴨，吊掛後槓桿仍保持\n水平平衡。此時臘肉使槓桿產生 0.2 kgw．m的逆時鐘力矩，若槓桿、細繩的質\n量與支點處的摩擦力皆忽略不計，則下列敘述何者正確？', '18.   有一種天氣系統，在西北太平洋稱為「颱風」，在澳洲附近則稱為「氣旋」，\n但兩者其實是相同的天氣系統，只是在不同地區採用不同的稱呼。下列有關\n颱風與氣旋的敘述，何者錯誤？', '19.   圖(十一)為某實驗的步驟圖，步驟四完成後，觀察到試管內的液體分成兩層。\n如果僅將其中的一個步驟修改，其他步驟不變，則下列四種修改方式及其結果\n的描述，何者正確？', '20.   某原子由質子、電子與中子三種粒子所組成，表(一)列出這些粒子的部分資訊(未依照\n順序)，根據這些資訊，判斷表格  、 、  與   填入的內容，何者是合理的？', '21.   圖(十二)為某種植物莖部橫切面的構造示意圖。已知「介殼蟲」是以此種植物\n韌皮部中的汁液為食，若想分析介殼蟲所吸取的成分，則應選擇圖中的哪一部\n位進行研究最合適？', '22.   當小庭看到驚悚畫面時，兩眼直視但身體刻意保持不動，而小瑋看到驚悚畫面\n時，則是大聲尖叫且用手遮眼。比較兩人從接受刺激到產生反應的相關敘述，\n下列何者最合理？', '23.   圖(十三)為板塊構造運動示意圖，甲、乙、丙分別代表三個地點。依據板塊構造\n學說的內容判斷，下列有關圖中板塊的敘述何者正確？', '24.   圖(十四)為人體內甲、乙兩種器官各自的動脈\n及靜脈血液中氧氣含量之示意圖。根據此圖推\n測，紅血球從獲得氧氣到釋出氧氣的運輸過程\n中，有關血液流經甲、乙及心臟的途徑，下列\n何者最合理？', '25.   已知水稻中某種特殊香味的性狀是由一對等位基因所控制，包含具此香味和\n不具此香味兩種特徵。某研究人員將皆不具此香味的水稻甲和乙進行授粉，\n其子代水稻丙不具有此香味，而子代水稻丁具有此香味。在不考慮突變的情況\n下，根據遺傳法則推測水稻甲、乙、丙及丁的基因型，下列何者無法確定？', '26.   怡君在夜市玩射飛鏢，她將三支飛鏢射在旋轉圓盤上的 5 20 1\n12 18\n甲、乙、丙三位置，飛鏢仍持續隨著圓盤中心旋轉，而旋 9 4\n14 13\n轉過程的某一瞬間如圖(十五)所示，若選項中箭頭僅代表力\n11 6\n的方向，則此時三支飛鏢所受的向心力方向為下列何者？', '27.   將導線鉛直穿過水平紙板，並在距導線東、南、\n西、北 2 cm 處放置磁針甲、乙、丙、丁，四個\n磁針 N 極均指向北方，如圖(十六)所示。通以方向\n向下的電流後，發現有三個磁針 N 極未指向北方，\n接著改通以方向向上、大小相同的電流後，發現也\n有三個磁針 N 極未指向北方，則四個磁針在先後兩\n次通電時，磁針 N 極均未指向北方的是哪兩個？', '28.   阿永取 1 L 的 0.5 M 氯化鋇 (BaCl ) 水溶液與 1 L 的 0.5 M 硫酸鈉 (Na SO ) 水溶\n2 2 4\n液混合，立刻產生白色沉澱。他將溶液過濾，取出沉澱物進一步實驗，確認成\n分為硫酸鋇，含量為 0.5 莫耳，而過濾後的澄清濾液，經測試發現在室溫時具有\n良好的導電性，則濾液中「主要的」導電粒子為下列何者？', '29.   表(二)中兩個音階的唱名同為 Do，但中央 C 與高音 C  表(二)\n的頻率卻不相同。若兩者在相同條件空氣中的傳播速率\nλ\n相同，波長分別為λ 、λ ，則   1  為多少？', '30.   圖(十七)為小珊進行 X、Y、Z 三個實驗的裝置示意圖，已知此三實驗均有氣體\n產生，且實驗 Y 與實驗 Z 反應開始後，前 30 秒所產生的氣體均不收集，則甲、\n乙、丙、丁四支試管，哪兩支試管所收集到的氣體具有可燃性？', '31.   甲、乙、丙、丁四個經度相同的地點，其緯度與海拔高度資料如表(三)所示。在\n四個地點鉛直立起高度相同的旗桿，於正午日照下投影到水平地面的桿影長度\n分別為 L 、L 、L 、L 。若不考慮天氣與地形遮蔽等因素，在北半球夏至正\n甲 乙 丙 丁\n午時，關於 L 、L 、L 、L 的大小關係，下列何者正確？', '32.   如圖(十八)所示，將五個完全相同的木塊以細線連接，再以固定的水平力 F 拉動\n木塊，使五個木塊以相同速度在無摩擦力的水平桌面上作直線運動。剛開始五\n個木塊的加速度大小同為 2 m/s2，一段時間後，將某一位置的細線剪斷，已知剪\n斷後仍被相同的水平力 F 拉動的木塊其加速度變為 2.5 m/s2，若忽略細線質量，\n則剪斷細線的位置，應是圖上 P、Q、R、S 哪一個位置？', '33.   某一終年有冰雪覆蓋的小島，島上冰雪\n覆蓋面積百分比隨時間的變化情形如圖\n(十九)所示。根據圖(十九)推測，此種變\n化週期與下列何者的週期最相近？', '34.   圖(二十)為小毅某次考卷的部分內容：\n3\n圖(二十)\n此題小毅答錯，老師要他回去訂正，則他只需修改第一行算式中的哪一個數值，\n就能獲得正確答案？', '35.   老師在上「元素與化合物」的課程時，要求學生分組討論後，在小卡上分別寫\n出元素和化合物各一個例子，下列哪一組的舉例最符合老師的要求？', '36.   若將主要影響臺灣 5、6 月天氣的鋒面稱為鋒面甲，影響 11、12 月天氣的鋒面\n稱為鋒面乙，則下列對於上述鋒面的敘述，何者正確？', '37.   表(四)為海中四種動物的代號、名稱及特徵，若要以脊椎骨的有無作為分類依\n據，則下列哪一分類結果最合理？', '38.   圖(二十一)為人體進行呼吸運動時，橫膈位置變動的示意圖。利用藍色氯化亞鈷\n試紙可檢測人體呼出氣體中的某物質。有關呼氣時橫膈位置的變化及可使試紙\n變色的物質，下列何者正確？', '39.   桌面上由左至右擺放著紅色、白色、綠色三張\n相鄰的圖卡，左端放置一平面鏡與桌面垂直，\ ...
# 104 Nature 1 1.   圖(一)是生物進行某種生理作用的示意圖，圖中箭頭 (cid:31)(cid:30)(cid:29)(cid:28)
# 代表能量或物質在葉片中的進出，此生理作用最可
# (cid:30)(cid:25)
# 能是下列何者？
# 104 Nature 2 2.   小臻取石墨、硫、鋁和銀四種物質中的其中一個，來進行如圖(二)所示的二個
# 實驗，根據實驗結果判斷，她最可能是取哪一個物質來進行實驗？
# 104 Nature 3 3.   小樺突然想到海邊觀察星象，而去請教氣象專家。專家說現在天氣圖上本地
# 是被標記為「L」的天氣系統籠罩，建議他改天再去。專家會做出如此建議，可
# 能是當此天氣系統籠罩時，將會造成下列何種影響？
# 104 Nature 4 4.   某人分別於甲、乙二區種植具有抗蟲基因的棉花及一般棉花，中間以道路相隔，
# 如圖(三)所示。經過一段時間後，發現乙區的棉花也具有此抗蟲基因，產生此現
# 象的原因，最可能是棉花的下列哪一構造傳播所造成？
# 104 Nature 5 5.   若以箭頭方向表示電流方向，則下列選項中哪一個電路裝置表示的電流方向正
# 確？
# 104 Nature 6 6.   某地區樹林中棲息著一種蛾，依身體顏色可分成深色蛾和淺色蛾，其主要的天敵
# 為鳥類。圖(四)為某段期間內深色蛾及淺色蛾數量變化的示意圖，圖中灰色部分標
# 記為甲、乙兩時期。若依天擇說解釋甲或乙時期蛾的數量變化，下列何者最合理？
# 104 Nature 7 7.   圖(五)為某古裝劇的一段對話，部分劇情雖為杜撰，但對話中所提到的內容符合
# 科學原理。已知草灰水溶液為鹼性，根據對話內容，判斷圖中進行了何種類型
# 的反應？
# 104 Nature 8 8.   阿問以手施一大小為 F 的作用力，水平向東推木樁，木樁仍然立著不動，手受
# 到木樁回推一個反作用力。關於其反作用力的作用情形，下列何者正確？
# 104 Nature 9 9.   下列何者不是搬運作用的現象？
# 104 Nature 10 10.   小琪要從圖(六)的甲、乙兩罐藥瓶中取出適量藥品進行實驗，根據
# 藥品名稱判斷，最適合取用此兩種藥品的器材分別為下列何者？
# 104 Nature 11 11.   有五個大小不同的實心金屬球，小莉分別將這些金屬球丟入水中，利用金屬球
# 排開水的體積來量得這些金屬球的體積(V)，並以天平量測其質量(M)，最後將
# 結果描繪如圖(七)。她發現圖上各點恰可連成一條直線，且此直線通過原點，則
# 她提出下列哪一個說明來解釋此一現象最合適？
# 104 Nature 12 12.   圖(八)為一則新聞報導的畫面與資訊，報導中指出：「一輛載運廢土的砂石車
# 突然起火，消防人員灑水灌救，反而造成爆炸。原來是廢土中含有鋁粉，遇到
# 熱水會激烈反應，甚至會爆炸。鋁為活性很大的物質……。」下列哪一類的元
# 素碰到水會進行和上述鋁粉碰到熱水相似的反應？
# 104 Nature 13 13.   下列關於溫室效應與全球暖化現象的說明，何者最為合理？
# 104 Nature 14 14.   一條彈簧的上端固定於支架上，下端未吊掛物體時，彈簧的長度為 10 cm。在
# 其下方吊掛一個質量未知的物體甲，彈簧的總長度變為 12 cm，接著在物體甲的
# 下方，再加掛一個 60 g 的砝碼，則彈簧的總長度變為 15 cm。若移除物體甲與
# 砝碼後，彈簧恢復原長，則物體甲的質量應為多少？
# 104 Nature 15 15.   如圖(九)所示，甲、乙為一臺複式顯微鏡上兩種不同倍率
# 的物鏡。小閔使用此顯微鏡觀察口腔皮膜細胞，他按照
# 使用顯微鏡的標準步驟依序開始操作，有關物鏡的轉換
# 及視野亮度的變化，下列敘述何者最合理？
# 104 Nature 16 16.   「地球到太陽的平均距離」為 1 天文單位。下列敘述中的距離，何者大於
# 1 天文單位？
# 104 Nature 17 17.   如圖(十)所示，在一個槓桿兩側分別以細繩吊掛臘肉與烤鴨，吊掛後槓桿仍保持
# 水平平衡。此時臘肉使槓桿產生 0.2 kgw．m的逆時鐘力矩，若槓桿、細繩的質
# 量與支點處的摩擦力皆忽略不計，則下列敘述何者正確？
# 104 Nature 18 18.   有一種天氣系統，在西北太平洋稱為「颱風」，在澳洲附近則稱為「氣旋」，
# 但兩者其實是相同的天氣系統，只是在不同地區採用不同的稱呼。下列有關
# 颱風與氣旋的敘述，何者錯誤？
# 104 Nature 19 19.   圖(十一)為某實驗的步驟圖，步驟四完成後，觀察到試管內的液體分成兩層。
# 如果僅將其中的一個步驟修改，其他步驟不變，則下列四種修改方式及其結果
# 的描述，何者正確？
# 104 Nature 20 20.   某原子由質子、電子與中子三種粒子所組成，表(一)列出這些粒子的部分資訊(未依照
# 順序)，根據這些資訊，判斷表格  、 、  與   填入的內容，何者是合理的？
# 104 Nature 21 21.   圖(十二)為某種植物莖部橫切面的構造示意圖。已知「介殼蟲」是以此種植物
# 韌皮部中的汁液為食，若想分析介殼蟲所吸取的成分，則應選擇圖中的哪一部
# 位進行研究最合適？
# 104 Nature 22 22.   當小庭看到驚悚畫面時，兩眼直視但身體刻意保持不動，而小瑋看到驚悚畫面
# 時，則是大聲尖叫且用手遮眼。比較兩人從接受刺激到產生反應的相關敘述，
# 下列何者最合理？
# 104 Nature 23 23.   圖(十三)為板塊構造運動示意圖，甲、乙、丙分別代表三個地點。依據板塊構造
# 學說的內容判斷，下列有關圖中板塊的敘述何者正確？
# 104 Nature 24 24.   圖(十四)為人體內甲、乙兩種器官各自的動脈
# 及靜脈血液中氧氣含量之示意圖。根據此圖推
# 測，紅血球從獲得氧氣到釋出氧氣的運輸過程
# 中，有關血液流經甲、乙及心臟的途徑，下列
# 何者最合理？
# 104 Nature 25 25.   已知水稻中某種特殊香味的性狀是由一對等位基因所控制，包含具此香味和
# 不具此香味兩種特徵。某研究人員將皆不具此香味的水稻甲和乙進行授粉，
# 其子代水稻丙不具有此香味，而子代水稻丁具有此香味。在不考慮突變的情況
# 下，根據遺傳法則推測水稻甲、乙、丙及丁的基因型，下列何者無法確定？
# 104 Nature 26 26.   怡君在夜市玩射飛鏢，她將三支飛鏢射在旋轉圓盤上的 5 20 1
# 12 18
# 甲、乙、丙三位置，飛鏢仍持續隨著圓盤中心旋轉，而旋 9 4
# 14 13
# 轉過程的某一瞬間如圖(十五)所示，若選項中箭頭僅代表力
# 11 6
# 的方向，則此時三支飛鏢所受的向心力方向為下列何者？
# 104 Nature 27 27.   將導線鉛直穿過水平紙板，並在距導線東、南、
# 西、北 2 cm 處放置磁針甲、乙、丙、丁，四個
# 磁針 N 極均指向北方，如圖(十六)所示。通以方向
# 向下的電流後，發現有三個磁針 N 極未指向北方，
# 接著改通以方向向上、大小相同的電流後，發現也
# 有三個磁針 N 極未指向北方，則四個磁針在先後兩
# 次通電時，磁針 N 極均未指向北方的是哪兩個？
# 104 Nature 28 28.   阿永取 1 L 的 0.5 M 氯化鋇 (BaCl ) 水溶液與 1 L 的 0.5 M 硫酸鈉 (Na SO ) 水溶
# 2 2 4
# 液混合，立刻產生白色沉澱。他將溶液過濾，取出沉澱物進一步實驗，確認成
# 分為硫酸鋇，含量為 0.5 莫耳，而過濾後的澄清濾液，經測試發現在室溫時具有
# 良好的導電性，則濾液中「主要的」導電粒子為下列何者？
# 104 Nature 29 29.   表(二)中兩個音階的唱名同為 Do，但中央 C 與高音 C  表(二)
# 的頻率卻不相同。若兩者在相同條件空氣中的傳播速率
# λ
# 相同，波長分別為λ 、λ ，則   1  為多少？
# 104 Nature 30 30.   圖(十七)為小珊進行 X、Y、Z 三個實驗的裝置示意圖，已知此三實驗均有氣體
# 產生，且實驗 Y 與實驗 Z 反應開始後，前 30 秒所產生的氣體均不收集，則甲、
# 乙、丙、丁四支試管，哪兩支試管所收集到的氣體具有可燃性？
# 104 Nature 31 31.   甲、乙、丙、丁四個經度相同的地點，其緯度與海拔高度資料如表(三)所示。在
# 四個地點鉛直立起高度相同的旗桿，於正午日照下投影到水平地面的桿影長度
# 分別為 L 、L 、L 、L 。若不考慮天氣與地形遮蔽等因素，在北半球夏至正
# 甲 乙 丙 丁
# 午時，關於 L 、L 、L 、L 的大小關係，下列何者正確？
# 104 Nature 32 32.   如圖(十八)所示，將五個完全相同的木塊以細線連接，再以固定的水平力 F 拉動
# 木塊，使五個木塊以相同速度在無摩擦力的水平桌面上作直線運動。剛開始五
# 個木塊的加速度大小同為 2 m/s2，一段時間後，將某一位置的細線剪斷，已知剪
# 斷後仍被相同的水平力 F 拉動的木塊其加速度變為 2.5 m/s2，若忽略細線質量，
# 則剪斷細線的位置，應是圖上 P、Q、R、S 哪一個位置？
# 104 Nature 33 33.   某一終年有冰雪覆蓋的小島，島上冰雪
# 覆蓋面積百分比隨時間的變化情形如圖
# (十九)所示。根據圖(十九)推測，此種變
# 化週期與下列何者的週期最相近？
# 104 Nature 34 34.   圖(二十)為小毅某次考卷的部分內容：
# 3
# 圖(二十)
# 此題小毅答錯，老師要他回去訂正，則他只需修改第一行算式中的哪一個數值，
# 就能獲得正確答案？
# 104 Nature 35 35.   老師在上「元素與化合物」的課程時，要求學生分組討論後，在小卡上分別寫
# 出元素和化合物各一個例子，下列哪一組的舉例最符合老師的要求？
# 104 Nature 36 36.   若將主要影響臺灣 5、6 月天氣的鋒面稱為鋒面甲，影響 11、12 月天氣的鋒面
# 稱為鋒面乙，則下列對於上述鋒面的敘述，何者正確？
# 104 Nature 37 37.   表(四)為海中四種動物的代號、名稱及特徵，若要以脊椎骨的有無作為分類依
# 據，則下列哪一分類結果最合理？
# 104 Nature 38 38.   圖(二十一)為人體進行呼吸運動時，橫膈位置變動的示意圖。利用藍色氯化亞鈷
# 試紙可檢測人體呼出氣體中的某物質。有關呼氣時橫膈位置的變化及可使試紙
# 變色的物質，下列何者正確？
# 104 Nature 39 39.   桌面上由左至右擺放著紅色、白色、綠色三張
# 相鄰的圖卡，左端放置一平面鏡與桌面垂直，
# 圖卡間相鄰位置與平面鏡上 P 點的角度關係，
# 如圖(二十二)所示。今將藍色光線以入射角 X 度
# 入射在平面鏡 P 點，看見光線反射後落在圖卡
# 上形成藍色光點，依上述條件推論，下列何者
# 最可能為 X 的數值？
# 104 Nature 40 40.   已知二氧化碳、葡萄糖的分子量分別為 44、180。葡萄糖在無氧密閉環境中經由
# 酵母菌發酵的反應式為：
# 酵母菌
# C H O  2 C H OH + 2 CO
# 6 12 6                     2 5 2
# 現有 3 × 1024 個葡萄糖分子，經由酵母菌發酵後，最多約可產生 C H OH 多少公克？
# 104 Nature 41 41.   唾液中的甲物質可催化澱粉的分解，胃液中的乙物質則可催化蛋白質的分解，
# 若推測甲、乙兩物質本身的主要成分，下列敘述何者最合理？
# 104 Nature 42 42.   老師請阿民和阿仁各設計一個電路，此電路需同時達到下列三個要求：
# 1、包含三個電阻器和一個電池。
# 2、流過三個電阻器的電流大小相同。
# 3、三個電阻器的電功率相同。
# 阿民和阿仁設計的電路圖如圖(二十三)所示，
# 若忽略導線電阻和電池內電阻，則關於兩人的
# 設計圖是否符合老師的三個要求，下列何者正確？
# 104 Nature 43 43.   圖(二十四)為自然界中氮循環部分途徑的示意圖，其中甲、乙為能進行氮的轉變
# 反應之生物。依此圖推斷甲、乙所屬的生物類別，下列何者最合理？
# 104 Nature 44 44.   一個實驗裝置如圖(二十五)所示，在兩個彈簧秤下方
# 分別吊掛重物甲、乙，再將重物浸入純水中，待重物
# 靜止後，兩個彈簧秤的讀數皆為 100 gw。已知甲、乙
# 的質量分別為 200 g、300 g，若甲、乙的密度分別為
# D 、D ，則 D ：D 最接近下列何者？
# 104 Nature 45 45.   某次出遊時，小明朝自己頭頂附近的天空拍攝得到甲照片，在 30 天內的某日
# 舊地重遊，於同一地點朝自己頭頂附近的天空拍攝得到乙照片，兩張照片如圖
# (二十六)所示，其中白色部分是當時小明看到的月相。圖(二十七)是月球、地球
# 與太陽光相對關係示意圖，黑點代表地球北極，參考圖(二十七)並根據月相與拍
# 攝方位判斷，下列有關兩照片拍攝時間間隔的推論，何者較合理？
# 104 Nature 46 46.   圖(二十八)為小怡在 20℃ 時進行實驗的步驟示意圖：
# 圖(二十八)
# 若溶解醋酸鈉 (CH COONa) 的過程中，溶液溫度均維持 20℃，根據實驗結果可
# 3
# 知，在 20℃ 時飽和的醋酸鈉水溶液，其重量百分濃度會在下列哪一個範圍內？
# 104 Nature 47 47.   根據本文，關於茭白筍的敘述，下列何者最合理？
# 104 Nature 48 48.   茭白筍內出現的黑點如圖(二十九)所示。根據本文，黑點可能是由
# 下列何者所組成？
# 104 Nature 49 49.   根據圖中判斷，從正常狀態到形成「無水氨」，最可能經過下列何種過程？
# 104 Nature 50 50.   根據文中所述，「無水氨」和硝酸根離子進行反應時的反應類型，依序為下列
# 何者？
# 104 Nature 51 51.   下列四者是筱喬根據她的紀錄，提出關於甲點岩層的說明或推論，則四者中何
# 者最不合理？
# 104 Nature 52 52.   根據老師的結論，若筱喬在甲點進行檢測實驗時，收集產生的氣泡並通入蒸餾水
# 中，則形成溶液的過程，[H+]和 pH 值分別會有何種變化？
# 104 Nature 53 53.   地質考察結束後，筱喬想將乙點的岩層剖面示意圖繪製完整，根據紀錄內容判
# 斷，筱喬完成的圖最可能是下列何者？
# 104 Nature 54 54.   若下列選項中，有一項為筱喬進行野外觀察時，起點至終點間的路徑長 (d) 與
# 時間 (t) 關係圖，其中各時間點的路徑長均對應起點，考慮筱喬行進時速率的合
# 理性及此圖的正確性，假設筱喬在各點停留觀察時均站立不動，則此圖最可能
# 為下列何者？
# done

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
