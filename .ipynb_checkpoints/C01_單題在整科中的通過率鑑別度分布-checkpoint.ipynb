# %%
#分析通過率
import math
import re
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

from matplotlib.font_manager import FontProperties
#myfont = FontProperties(fname='/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc')
myfont = FontProperties(fname=r'C:\Windows\Fonts\NotoSansCJKtc-Regular.otf')

# %%
passing_df = pd.read_csv('合併後的通過率與鑑別度.csv')  
print(passing_df)
# Out:
#        年度  科目  題號   鑑別度   通過率
# 0     109  國文   1  0.36  0.92
# 1     109  國文   2  0.32  0.91
# 2     109  國文   3  0.33  0.95
# 3     109  國文   4  0.41  0.91
# 4     109  國文   5  0.41  0.90
# 5     109  國文   6  0.49  0.87
# 6     109  國文   7  0.43  0.75
# 7     109  國文   8  0.43  0.73
# 8     109  國文   9  0.35  0.81
# 9     109  國文  10  0.43  0.70
# 10    109  國文  11  0.47  0.74
# 11    109  國文  12  0.52  0.74
# 12    109  國文  13  0.34  0.65
# 13    109  國文  14  0.51  0.74
# 14    109  國文  15  0.46  0.71
# 15    109  國文  16  0.56  0.68
# 16    109  國文  17  0.53  0.70
# 17    109  國文  18  0.49  0.65
# 18    109  國文  19  0.49  0.69
# 19    109  國文  20  0.41  0.60
# 20    109  國文  21  0.46  0.57
# 21    109  國文  22  0.42  0.49
# 22    109  國文  23  0.48  0.63
# 23    109  國文  24  0.38  0.50
# 24    109  國文  25  0.46  0.45
# 25    109  國文  26  0.35  0.55
# 26    109  國文  27  0.44  0.62
# 27    109  國文  28  0.42  0.50
# 28    109  國文  29  0.50  0.50
# 29    109  國文  30  0.36  0.48
# ...   ...  ..  ..   ...   ...
# 1716  103  自然  25  0.54  0.50
# 1717  103  自然  26  0.48  0.50
# 1718  103  自然  27  0.51  0.51
# 1719  103  自然  28  0.53  0.62
# 1720  103  自然  29  0.54  0.50
# 1721  103  自然  30  0.61  0.44
# 1722  103  自然  31  0.58  0.39
# 1723  103  自然  32  0.49  0.36
# 1724  103  自然  33  0.46  0.45
# 1725  103  自然  34  0.43  0.26
# 1726  103  自然  35  0.53  0.43
# 1727  103  自然  36  0.46  0.43
# 1728  103  自然  37  0.50  0.47
# 1729  103  自然  38  0.51  0.35
# 1730  103  自然  39  0.50  0.50
# 1731  103  自然  40  0.45  0.26
# 1732  103  自然  41  0.52  0.41
# 1733  103  自然  42  0.49  0.26
# 1734  103  自然  43  0.40  0.31
# 1735  103  自然  44  0.57  0.30
# 1736  103  自然  45  0.43  0.25
# 1737  103  自然  46  0.29  0.26
# 1738  103  自然  47  0.55  0.71
# 1739  103  自然  48  0.50  0.63
# 1740  103  自然  49  0.45  0.70
# 1741  103  自然  50  0.43  0.58
# 1742  103  自然  51  0.52  0.42
# 1743  103  自然  52  0.49  0.46
# 1744  103  自然  53  0.48  0.62
# 1745  103  自然  54  0.44  0.38
#
# [1746 rows x 5 columns]

# %%
subject = '自然'
x = passing_df[passing_df['科目'] == subject]['通過率']
y = passing_df[passing_df['科目'] == subject]['鑑別度']

fig, ax = plt.subplots()

#畫出所有的題目
ax.plot(x, y, marker='o', linestyle='', ms=5,color =((0.1, 0.1, 0.1, 0.15)))

#畫出單題
item_x = 0.2
item_y = 0.4
ax.plot(item_x, item_y, marker='o', linestyle='', ms=5,color =((1, 0, 0, 0.9)))
ax.text(0.1, 0.7, 'test' , fontsize = 12)


ax.set_title(subject, fontproperties=myfont)
ax.set_xlabel('通過率' , fontproperties=myfont)
ax.set_ylabel('鑑別度' , fontproperties=myfont)
ax.grid()
ax.set_xticks((0, 0.5, 1))
ax.set_yticks((0, 0.2, 0.5, 1))

ax.set_xlim([0, 1])
ax.set_ylim([0, 0.8])



plt.savefig('探究實作題目/plot.png', dpi = 150)
plt.show()

# %%
inquiry_df = pd.read_csv('會考題目/探究實作題目.csv')  
print(inquiry_df)
# Out:
#     slide順序   年度  題號                      分類
# 0         1  103  10                 實驗器材使用
# 1         2  103  47             圖表製作：資料轉圖表
# 2         3  104  19  實驗設計：材料選用-如果換成OO，會怎樣？
# 3         4  104  11        從圖表推論原因-為什麼會這樣?
# 4         5  105  21           實驗設計：怎麼設計實驗？
# 5         6  105   8  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 6         7  105  15  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 7         8  106  47            實驗設計：實驗變因選擇
# 8         9  106  33             圖表製作：資料轉圖表
# 9        10  106  11     圖表判讀：讀圖的能力，在圖表中比大小
# 10       11  106  21                   圖表判讀
# 11       12  106  48                   圖表判讀
# 12       13  107   8           實驗設計：怎麼設計實驗？
# 13       14  107  35        從圖表推論原因-為什麼會這樣?
# 14       15  107  53  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 15       16  108  33             圖表判讀：讀圖的能力
# 16       17  108  11        從圖表推論原因-為什麼會這樣?
# 17       18  108  51  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 18       19  108   3  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 19       20  108  45                   圖表判讀
# 20       21  108  38                   論證反駁
# 21       22  109  19     圖表判讀：讀圖的能力，在圖表中比大小
# 22       23  109  54           圖表製作：從結論反推資料
# 23       24  109  21           圖表製作：從結論反推資料
# 24       25  110   1                 實驗器材使用
# 25       26  110  50           實驗設計：想要研究什麼？
# 26       27  110  22    實驗設計：實驗目的、改變步驟、解讀圖表
# 27       28  110  32        從圖表推論原因-為什麼會這樣?
# 28       29  110  11  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 29       30  110  48  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 30       31  110   7  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 31       32  110  45           圖表製作：從結論反推資料
# 32       33  110   8                   論證反駁
# 33       34  111  47           實驗設計：想要研究什麼？
# 34       35  111  50    實驗設計：材料選用-為什麼用這個材料？
# 35       36  111  14  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 36       37  111  44  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 37       38  111  45  圖表判讀：從圖表獲得結論-這代表什麼意思？
# 38       39  111  24                   圖表判讀

# %%
def drawImage(year, quesiton_num, item_pass,item_discri):
    subject = '自然'
    x = passing_df[passing_df['科目'] == subject]['通過率']
    y = passing_df[passing_df['科目'] == subject]['鑑別度']

    fig, ax = plt.subplots()

    #畫出所有的題目
    ax.plot(x, y, marker='o', linestyle='', ms = 7,color = ((0.1, 0.1, 0.1, 0.15)))

    #畫出單題
    #item_pass = 0.2
    #item_discri = 0.4
    ax.plot(item_pass, item_discri, marker='o', linestyle='', ms=5,color =((1, 0, 0, 0.9)))
    ax.text(0.1, 0.7, str(year) + '年' , fontsize = 30, fontproperties=myfont)
    ax.text(0.1, 0.65, str(quesiton_num) + '題' , fontsize = 20, fontproperties=myfont)
    ax.text(0.1, 0.60, '通過率:' + str(item_pass) , fontsize = 20, fontproperties=myfont)
    ax.text(0.1, 0.55, '鑑別度:' + str(item_discri) , fontsize = 20, fontproperties=myfont)
    
    


    ax.set_title(subject,  fontsize = 20, fontproperties=myfont)
    ax.set_xlabel('通過率' , fontsize = 20, fontproperties=myfont)
    ax.set_ylabel('鑑別度' , fontsize = 20, fontproperties=myfont)
    ax.grid()
    ax.set_xticks((0, 0.5, 1))
    ax.set_yticks((0, 0.2, 0.5, 1))

    ax.set_xlim([0, 1])
    ax.set_ylim([0, 0.8])



    plt.savefig('探究實作題目/'+ str(year) + '_' + str(quesiton_num) +'.png', dpi = 100)
    plt.show()

# %%
#for i in range(inquiry_df.shape[0]):
for i in range(1):    
    year = inquiry_df['年度'].iloc[i]
    quesiton_num = inquiry_df['題號'].iloc[i]
    if year <= 109:

        filter_1 = passing_df['科目'] == subject
        filter_2 = passing_df['年度'] == year
        filter_3 = passing_df['題號'] == quesiton_num

        item_pass = passing_df[filter_1 & filter_2 & filter_3]['通過率'].values[0]
        item_discri = passing_df[filter_1 & filter_2 & filter_3]['鑑別度'].values[0]
        print(year, quesiton_num, item_pass,item_discri)
        drawImage(year, quesiton_num, item_pass,item_discri)
        #print(item_discri)
# Out:
# 103 10 0.66 0.44
